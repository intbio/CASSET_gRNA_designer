# %% [markdown]
# # ToDo:
# - проверить поиск с пам

# %%
from Bio import Entrez
from Bio import SeqIO
from Bio.Seq import Seq
from Bio.SeqRecord import SeqRecord
Entrez.email = 'akgribkova@gmail.com' 
import re

# %%
from Bio.Blast import NCBIWWW
from Bio import SeqIO
from Bio.Blast import NCBIXML

# %% [markdown]
# ## примеры qblast

# %%
#help(NCBIWWW.qblast)

# %% [markdown]
# The degenerate nucleotide codes in red are treated as mismatches in nucleotide alignment. Too many such degenerate codes within an input nucleotide query will cause the BLAST webpage to reject the input. For protein queries, too many nucleotide-like code (A,C,G,T,N) may also cause similar rejection.
# K  G/T (keto)         S  G/C (strong)         Y  T/C (pyrimidine)
# 		M  A/C (amino)        W  A/T (weak)           R  G/A (purine)
# 		B  G/T/C              D  G/A/T                H  A/C/T
# 		V  G/C/A              -  gap of indeterminate length

# %% [markdown]
# - For nucleotide-nucleotide searches (i.e., "blastn") an exact match of the entire word is required before an extension is initiated, so that one normally regulates the sensitivity and speed of the search by increasing or decreasing the word-size.
# - Reward and Penalty for Nucleotide Programs
# Many nucleotide searches use a simple scoring system that consists of a "reward" for a match and a "penalty" for a mismatch. The (absolute) reward/penalty ratio should be increased as one looks at more divergent sequences. **A ratio of 0.33 (1/-3) is appropriate for sequences that are about 99% conserved DEFAULT**; a ratio of 0.5 (1/-2) is best for sequences that are 95% conserved; a ratio of about one (1/-1) is best for sequences that are 75% conserved [1]. Read more here [1] States DJ, Gish W, and Altschul SF (1991) METHODS: A companion to Methods in Enzymology 3:66-70.

# %% [markdown]
#  NCBIWWW.qblast("blastn", "nt", 'TTACAGTTAAGCTACCTTATGC', nucl_reward=1, nucl_penalty=-2, hitlist_size=1000, word_size = 7)
#  - получилось 137 таргетов с hsp.gaps ==0

# %% [markdown]
# The "Search for short, nearly exact matches" nucleotide and protein pages no longer exist. Instead, the nucleotide and protein blast programs automatically check for short queries and adjust the search parameters accordingly. This adjustment occurs when the query, either nucleotide or amino acid, is of length 30 or less. The translating blast programs or searches on the genome blast pages do not have this auto adjust feature.

# %%
# %%time
result_handle = NCBIWWW.qblast("blastn", "nt", 'GCTTTTTAACTATTTGATCTCT', nucl_reward=1, nucl_penalty=-1, hitlist_size=1000, word_size = 5, expect=200000.0 )
                              #filter=False,
                              #composition_based_statistics=False,
                              #matrix_name="PAM30",) #NNGRRT #word_size = 11,
blast_record = NCBIXML.read(result_handle)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <timed exec> in <module>()
#
# /opt/miniconda3/envs/genomics/lib/python3.5/site-packages/Bio/Blast/NCBIXML.py in read(handle, debug)
#     743     iterator = parse(handle, debug)
#     744     try:
# --> 745         first = next(iterator)
#     746     except StopIteration:
#     747         first = None
#
# /opt/miniconda3/envs/genomics/lib/python3.5/site-packages/Bio/Blast/NCBIXML.py in parse(handle, debug)
#     831             if (NEW_LINE + XML_START) not in (text + pending):
#     832                 # Good - still dealing with the same XML file
# --> 833                 expat_parser.Parse(text, False)
#     834                 while blast_parser._records:
#     835                     yield blast_parser._records.pop(0)
#
# /tmp/build/80754af9/python_1535317565804/work/Modules/pyexpat.c in StartElement()
#
# /opt/miniconda3/envs/genomics/lib/python3.5/site-packages/Bio/Blast/NCBIXML.py in startElement(self, name, attr)
#      77         if self._value.strip():
#      78             raise ValueError("What should we do with %s before the %s tag?"
# ---> 79                              % (repr(self._value), name))
#      80         self._value = ""
#      81
#
# ValueError: What should we do with '\nCREATE_VIEW\n\n\n' before the Hit tag?

# %%
#hitlist_size   Number of hits to return. Default 50
#ncbi_gi= True,

# %%
#with open("targe_blast.xml", "w") as out_handle:
#    out_handle.write(result_handle.read())
#result_handle.close()
#result_handle = open("targe_blast.xml")

# %% [markdown]
# - если не хотим смотреть глазами на организмы, в которых найдены таргеты - прописываем gi тех, кого не хотим видеть

# %%
# не наш случай for multiple query sequences
#blast_records = NCBIXML.parse(result_handle)

# %%
E_VALUE_THRESH = 10

# %%
#a = []
for alignment in blast_record.alignments:
    for hsp in alignment.hsps:
        if hsp.expect < E_VALUE_THRESH:  
            print("****Alignment****")
            print("sequence:", alignment.title)
            print("length:", alignment.length)
            print("e value:", hsp.expect)
            print(hsp.query )
            print(hsp.match )
            print(hsp.sbjct )
            print(hsp.gaps)
            #print(hsp.score )
            #print(hsp.query_start )
            #print(hsp.sbjct_start )
            #print(hsp.strand )
            #a.append(hsp.gaps)
# Out:
# ****Alignment****
# sequence: gi|1758968360|gb|CP044535.1| Borrelia sp. CA690 chromosome, complete genome
# length: 902176
# e value: 0.431298
# GCTTTTTAACTATTTGATCTCT
# ||||||||||||||||||||||
# GCTTTTTAACTATTTGATCTCT
# 0
# ****Alignment****
# sequence: gi|1519327843|gb|CP028861.1| Borreliella garinii strain 20047 chromosome, complete genome
# length: 906449
# e value: 0.431298
# GCTTTTTAACTATTTGATCTCT
# ||||||||||||||||||||||
# GCTTTTTAACTATTTGATCTCT
# 0
# ****Alignment****
# sequence: gi|1519326699|gb|CP028872.1| Borreliella bavariensis PBi chromosome 1, complete sequence
# length: 905817
# e value: 0.431298
# GCTTTTTAACTATTTGATCTCT
# ||||||||||||||||||||||
# GCTTTTTAACTATTTGATCTCT
# 0
# ****Alignment****
# sequence: gi|1444370355|gb|CP031412.1| Borreliella burgdorferi strain MM1 chromosome main, complete sequence
# length: 908512
# e value: 0.431298
# GCTTTTTAACTATTTGATCTCT
# ||||||||||||||||||||||
# GCTTTTTAACTATTTGATCTCT
# 0
# ****Alignment****
# sequence: gi|1249983421|gb|CP017201.1| Borreliella burgdorferi strain B331 chromosome, complete genome
# length: 904573
# e value: 0.431298
# GCTTTTTAACTATTTGATCTCT
# ||||||||||||||||||||||
# GCTTTTTAACTATTTGATCTCT
# 0
# ****Alignment****
# sequence: gi|1194995826|gb|CP019767.1| Borrelia burgdorferi strain B31_NRZ, complete sequence
# length: 909921
# e value: 0.431298
# GCTTTTTAACTATTTGATCTCT
# ||||||||||||||||||||||
# GCTTTTTAACTATTTGATCTCT
# 0
# ****Alignment****
# sequence: gi|1194993776|gb|CP019916.1| Borreliella burgdorferi strain PAbe chromosome, complete genome
# length: 910728
# e value: 0.431298
# GCTTTTTAACTATTTGATCTCT
# ||||||||||||||||||||||
# GCTTTTTAACTATTTGATCTCT
# 0
# ****Alignment****
# sequence: gi|1194992532|gb|CP019844.1| Borreliella burgdorferi strain PAli, complete genome
# length: 909921
# e value: 0.431298
# GCTTTTTAACTATTTGATCTCT
# ||||||||||||||||||||||
# GCTTTTTAACTATTTGATCTCT
# 0
# ****Alignment****
# sequence: gi|1130735456|gb|CP015780.1| Borrelia mayonii strain MN14-1420, complete genome
# length: 904387
# e value: 0.431298
# GCTTTTTAACTATTTGATCTCT
# ||||||||||||||||||||||
# GCTTTTTAACTATTTGATCTCT
# 0
# ****Alignment****
# sequence: gi|1127877230|gb|CP015796.1| Borrelia mayonii strain MN14-1539 chromosome, complete genome
# length: 904387
# e value: 0.431298
# GCTTTTTAACTATTTGATCTCT
# ||||||||||||||||||||||
# GCTTTTTAACTATTTGATCTCT
# 0
# ****Alignment****
# sequence: gi|1123417675|gb|CP018744.1| Borreliella garinii strain CIP 103362 isolate 20047 chromosome, complete genome
# length: 905638
# e value: 0.431298
# GCTTTTTAACTATTTGATCTCT
# ||||||||||||||||||||||
# GCTTTTTAACTATTTGATCTCT
# 0
# ****Alignment****
# sequence: gi|1112966244|gb|CP018262.1| Borreliella afzelii strain BO23 chromosome, complete genome
# length: 905394
# e value: 0.431298
# GCTTTTTAACTATTTGATCTCT
# ||||||||||||||||||||||
# GCTTTTTAACTATTTGATCTCT
# 0
# ****Alignment****
# sequence: gi|782833356|gb|CP009058.1| Borrelia afzelii K78, complete genome
# length: 905949
# e value: 0.431298
# GCTTTTTAACTATTTGATCTCT
# ||||||||||||||||||||||
# GCTTTTTAACTATTTGATCTCT
# 0
# ****Alignment****
# sequence: gi|741042522|gb|CP009910.1| Borreliella chilensis strain VA1 chromosome, complete genome
# length: 900694
# e value: 0.431298
# GCTTTTTAACTATTTGATCTCT
# ||||||||||||||||||||||
# GCTTTTTAACTATTTGATCTCT
# 0
# ****Alignment****
# sequence: gi|672920733|gb|CP009212.1| Borrelia afzelii Tom3107, complete genome
# length: 905861
# e value: 0.431298
# GCTTTTTAACTATTTGATCTCT
# ||||||||||||||||||||||
# GCTTTTTAACTATTTGATCTCT
# 0
# ****Alignment****
# sequence: gi|635290980|gb|CP007564.1| Borrelia garinii SZ, complete genome
# length: 902487
# e value: 0.431298
# GCTTTTTAACTATTTGATCTCT
# ||||||||||||||||||||||
# GCTTTTTAACTATTTGATCTCT
# 0
# ****Alignment****
# sequence: gi|529194277|gb|CP005925.1| Borrelia burgdorferi CA382, complete genome
# length: 910736
# e value: 0.431298
# GCTTTTTAACTATTTGATCTCT
# ||||||||||||||||||||||
# GCTTTTTAACTATTTGATCTCT
# 0
# ****Alignment****
# sequence: gi|408536136|gb|CP003882.1| Borrelia afzelii HLJ01, complete genome
# length: 905471
# e value: 0.431298
# GCTTTTTAACTATTTGATCTCT
# ||||||||||||||||||||||
# GCTTTTTAACTATTTGATCTCT
# 0
# ****Alignment****
# sequence: gi|407240455|gb|CP003866.1| Borrelia garinii NMJW1, complete genome
# length: 902789
# e value: 0.431298
# GCTTTTTAACTATTTGATCTCT
# ||||||||||||||||||||||
# GCTTTTTAACTATTTGATCTCT
# 0
# ****Alignment****
# sequence: gi|365193444|gb|CP003151.1| Borrelia garinii BgVir chromosome linear, complete sequence
# length: 905534
# e value: 0.431298
# GCTTTTTAACTATTTGATCTCT
# ||||||||||||||||||||||
# GCTTTTTAACTATTTGATCTCT
# 0
# ****Alignment****
# sequence: gi|342856386|gb|CP002933.1| Borrelia afzelii PKo, complete genome
# length: 903609
# e value: 0.431298
# GCTTTTTAACTATTTGATCTCT
# ||||||||||||||||||||||
# GCTTTTTAACTATTTGATCTCT
# 0
# ****Alignment****
# sequence: gi|342222012|gb|CP002746.1| Borreliella bissettii DN127, complete genome
# length: 900755
# e value: 0.431298
# GCTTTTTAACTATTTGATCTCT
# ||||||||||||||||||||||
# GCTTTTTAACTATTTGATCTCT
# 0
# ****Alignment****
# sequence: gi|312148964|gb|CP002228.1| Borrelia burgdorferi N40, complete genome
# length: 902191
# e value: 0.431298
# GCTTTTTAACTATTTGATCTCT
# ||||||||||||||||||||||
# GCTTTTTAACTATTTGATCTCT
# 0
# ****Alignment****
# sequence: gi|312147736|gb|CP002312.1| Borrelia burgdorferi JD1, complete genome
# length: 922801
# e value: 0.431298
# GCTTTTTAACTATTTGATCTCT
# ||||||||||||||||||||||
# GCTTTTTAACTATTTGATCTCT
# 0
# ****Alignment****
# sequence: gi|218164353|gb|CP001205.1| Borrelia burgdorferi ZS7, complete genome
# length: 906707
# e value: 0.431298
# GCTTTTTAACTATTTGATCTCT
# ||||||||||||||||||||||
# GCTTTTTAACTATTTGATCTCT
# 0
# ****Alignment****
# sequence: gi|110890097|gb|CP000395.1| Borrelia afzelii PKo, complete genome
# length: 905394
# e value: 0.431298
# GCTTTTTAACTATTTGATCTCT
# ||||||||||||||||||||||
# GCTTTTTAACTATTTGATCTCT
# 0
# ****Alignment****
# sequence: gi|51572834|gb|CP000013.1| Borreliella bavariensis PBi, complete genome
# length: 904246
# e value: 0.431298
# GCTTTTTAACTATTTGATCTCT
# ||||||||||||||||||||||
# GCTTTTTAACTATTTGATCTCT
# 0
# ****Alignment****
# sequence: gi|6626249|gb|AE000783.1| Borrelia burgdorferi B31, complete genome
# length: 910724
# e value: 0.431298
# GCTTTTTAACTATTTGATCTCT
# ||||||||||||||||||||||
# GCTTTTTAACTATTTGATCTCT
# 0
# ****Alignment****
# sequence: gi|520779|gb|L32861.1|BORPLSCTOP Borrelia burgdorferi 1-acyl-sn-glycerol-3-phosphate acetyltransferase (plsC) gene, 3' end; topoisomerase IV beta-subunit (parE) gene, 5' end
# length: 677
# e value: 0.431298
# GCTTTTTAACTATTTGATCTCT
# ||||||||||||||||||||||
# GCTTTTTAACTATTTGATCTCT
# 0
# ****Alignment****
# sequence: gi|1777376521|emb|LR738555.1| Neostethus bicornis genome assembly, chromosome: 14
# length: 27895003
# e value: 1.50538
# CTTTTTAACTATTTGATCTCT
# |||||||||||||||||||||
# CTTTTTAACTATTTGATCTCT
# 0

# %%
len(a)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-17-1a2e6ec5f1e3> in <module>()
# ----> 1 len(a)
#
# NameError: name 'a' is not defined

# %% [markdown]
# ## Подгружаем готовые таргеты из другого ноутбука

# %%
def id_search(seq_id):
    handle=Entrez.efetch(db="nucleotide", id = seq_id, rettype='fasta')  
    for seq_record in SeqIO.parse(handle,'fasta'):
        return seq_record.seq

# %%
cas_info = {'SpCas9': {'pam_forw' : '[ACGT]GG', 'pam_rev' : 'CC[ACGT]', 'pam_len':3, 'len_target' : 20},
            'SaCas9': {'pam_forw' : '[ACGT][ACGT]G[AG][AG]T', 'pam_rev' : 'A[TC][TC]C[ACGT][ACGT]', 'pam_len':6, 'len_target' : 21}, 
            'CjCas9': {'pam_forw' : '[ACGT][ACGT][ACGT][ACGT]A[CT]AC', 'pam_rev' : 'GT[GA]T[ACGT][ACGT][ACGT][ACGT]', 'pam_len':8, 'len_target' : 22}, 
            'StCas9': { 'pam_forw' : '[ACGT][ACGT]AGAA[AT]', 'pam_rev' : '[CG]TTCT[ACGT][ACGT]', 'pam_len':7, 'len_target' : 20} }

# %%
cas_1 = 'CjCas9'
cas_2 = 'SaCas9'
orientation = 'PAM-in'

# %%
off_target_genome = id_search(alignment.title.split('|')[3])

if hsp.strand[1] == 'Minus':
    possible_pam = off_target_1[hsp.sbjct_start - cas_info[cas_1]['pam_len']:hsp.sbjct_start] 
else:
    possible_pam = off_target_1[hsp.sbjct_start + len(hsp.sbjct) : hsp.sbjct_start + len(hsp.sbjct) + cas_info[cas_1]['pam_len']:] 
res = re.match(cas_info[cas_1]['pam_rev'], str(possible_pam))         #str(possible_pam))
if res:
    print('yes')
else:
    print('no')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-3f81c94176d7> in <module>()
# ----> 1 off_target_genome = id_search(alignment.title.split('|')[3])
#       2
#       3 if hsp.strand[1] == 'Minus':
#       4     possible_pam = off_target_1[hsp.sbjct_start - cas_info[cas_1]['pam_len']:hsp.sbjct_start]
#       5 else:
#
# NameError: name 'alignment' is not defined

# %%
final = {}
final['CjCas9_SaCas9_PAM-in'] = {1: {'left': {'afzelii': {35743: 'GCTTTTTAACTATTTGATCTCT'},
   'bavariensis': {35777: 'GCTTTTTAACTATTTGATCTCT'},
   'burgdorferi': {35898: 'GCTTTTTAACTATTTGATCTCT'},
   'garenii': {35908: 'GCTTTTTAACTATTTGATCTCT'}},
  'right': {'afzelii': {35743: 'TTAATTTTAAAACATCTATCAA'},
   'bavariensis': {35777: 'TTAATTTTAAAACATCTATCAA'},
   'burgdorferi': {35898: 'TTAATTTTAAAACATCTATCAA'},
   'garenii': {35908: 'TTAATTTTAAAATATCTATCAA'}}},
 2: {'left': {'afzelii': {436838: 'TTACAGTTAAGCTACCTTATGC'},
   'bavariensis': {436536: 'TTACAGTTAAGCTACCTTATGC'},
   'burgdorferi': {439384: 'TTACAGTTAAGCTACCTTATGC'},
   'garenii': {435891: 'TTACAGTTAAGCTACCTTATGC'}},
  'right': {'afzelii': {436838: 'AGGTAACCTTTGCGCACCTCCG'},
   'bavariensis': {436536: 'AGGTAACCTTTGCGCACCTCCG'},
   'burgdorferi': {439384: 'AGGTAACCTTTGCGCACCTCCG'},
   'garenii': {435891: 'AGGTAACCTTTGCGCACCTCCG'}}},
 3: {'left': {'afzelii': {436878: 'CACGTTGAGACAGCGTCCAAAT'},
   'bavariensis': {436233: 'CACGTTGAGACAGCGTCCAAAT'},
   'burgdorferi': {436490: 'CACGTTGAGACAGCGTCCAAAT'},
   'garenii': {437180: 'CACGTTGAGACAGCGTCCAAAT'}},
  'right': {'afzelii': {436878: 'CAAGGAATTTCGCTACCTTAGG'},
   'bavariensis': {436233: 'CAAGGAATTTCGCTACCTTAGG'},
   'burgdorferi': {436490: 'CAAGGAATTTCGCTACCTTAGG'},
   'garenii': {437180: 'CAAGGAATTTCGCTACCTTAGG'}}},
 4: {'left': {'afzelii': {436838: 'TTACAGTTAAGCTACCTTATGC'},
   'bavariensis': {436536: 'TTACAGTTAAGCTACCTTATGC'},
   'burgdorferi': {439384: 'TTACAGTTAAGCTACCTTATGC'},
   'garenii': {435891: 'TTACAGTTAAGCTACCTTATGC'}},
  'right': {'afzelii': {436838: 'AGGTAACCTTTGCGCACCTCCG'},
   'bavariensis': {436536: 'AGGTAACCTTTGCGCACCTCCG'},
   'burgdorferi': {439384: 'AGGTAACCTTTGCGCACCTCCG'},
   'garenii': {435891: 'AGGTAACCTTTGCGCACCTCCG'}}}, }

# %%
[*final['CjCas9_SaCas9_PAM-in'][2]['left']['afzelii'].values() ][0][:12]
# Out:
# 'TTACAGTTAAGC'

# %%
def pathogen_targets_alignment(seq1, seq2, mismatches_thres_12, mismatches_thres_all ):

    mismatches_thres_12 = 2
    mismatches_thres_all = 4

    alignments = aligner.align(seq1[:12], seq2[:12])
    for alignment in alignments:
        if 12- alignment.score <= mismatches_thres_12:
            alignments = aligner.align(seq1, seq2)
            for alignment in alignments:
                if min(len(seq1), len(seq2)) - alignment.score <= mismatches_thres_all:
                    return True

# %%
pat_target_left = [*final['CjCas9_SaCas9_PAM-in'][3]['left']['afzelii'].values() ][0][:12]
result_handle = NCBIWWW.qblast("blastn", "nt", pat_target_left) #NNGRRT
blast_record = NCBIXML.read(result_handle)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-14-4a50dba10e62> in <module>()
#       1 pat_target_left = [*final['CjCas9_SaCas9_PAM-in'][3]['left']['afzelii'].values() ][0][:12]
# ----> 2 result_handle = NCBIWWW.qblast("blastn", "nt", pat_target_left) #NNGRRT
#       3 blast_record = NCBIXML.read(result_handle)
#
# NameError: name 'NCBIWWW' is not defined

# %%
pat_target_left
# Out:
# 'CACGTTGAGACA'

# %%
for alignment in blast_record.alignments:
    for hsp in alignment.hsps:
        if hsp.expect < E_VALUE_THRESH:
            print(hsp.expect)

# %%
def blast_search_targets(final ):

    #for num in final['CjCas9_SaCas9_PAM-in'].keys():
    for num in [4]:
        print('start {}'.format(num))
        # взяли первые 12-ть нуклеотидов первого таргет 
        pat_target_left = [*final['CjCas9_SaCas9_PAM-in'][num]['left']['afzelii'].values() ][0][:12]
        print('start blast')
        
        result_handle = NCBIWWW.qblast("blastn", "nt", pat_target_left, nucl_reward=1, nucl_penalty=-2, hitlist_size=100, word_size = 7)
        #result_handle = NCBIWWW.qblast("blastn", "nt", pat_target_left) #NNGRRT
        blast_record = NCBIXML.read(result_handle)
        print('end blast')
        for alignment in blast_record.alignments:
            possible_species = alignment.title
            # подгрузили геном off species
            off_target_genome = id_search(alignment.title.split('|')[3])
            print('start PAM searching in off_target_genome {}'.format(possible_species))
            for hsp in alignment.hsps:
                if hsp.expect < E_VALUE_THRESH:
                    off_target_start_1 = hsp.sbjct_start
                    # нашли пам для любого из двух кас в зависимости от того, на какой цепи таргет
                    
                    
                    if hsp.strand[1] == 'Minus':
                        possible_pam = off_target_genome[hsp.sbjct_start - cas_info[cas_1]['pam_len']:hsp.sbjct_start] 
                    else:
                        possible_pam = off_target_genome[hsp.sbjct_start + len(hsp.sbjct) : hsp.sbjct_start + len(hsp.sbjct) + cas_info[cas_1]['pam_len']] 
                    
                    res = re.match(cas_info[cas_1]['pam_rev'], str(possible_pam))   
                    if res:
                        print('Result for matching 2 Cas proteins on left pat target: {}'.format(decision) )
                            
                        pat_target_right = [*final['CjCas9_SaCas9_PAM-in'][num]['right']['afzelii'].values() ][0][:12]
                        print('start blast for second target')
                        result_handle = NCBIWWW.qblast("blastn", "nt", pat_target_left) #NNGRRT
                        blast_record = NCBIXML.read(result_handle)
                        print('end blast for second target')
                        for alignment in blast_record.alignments:
                            if alignment.title == possible_species:
                                for hsp in alignment.hsps:
                                    if hsp.expect < E_VALUE_THRESH:
                                        off_target_start_2 = hsp.sbjct_start
                                            
     
                                        if hsp.strand[1] == 'Minus':
                                            possible_pam = off_target_genome[hsp.sbjct_start - cas_info[cas_2]['pam_len']:hsp.sbjct_start] 
                                        else:
                                            possible_pam = off_target_genome[hsp.sbjct_start + len(hsp.sbjct) : hsp.sbjct_start + len(hsp.sbjct) + cas_info[cas_2]['pam_len']:]
                                                
                                        res = re.match(cas_info[cas_1]['pam_rev'], str(possible_pam))   
                                        if res:
                                            print('Result for matching 2 Cas proteins on right pat target: {}'.format(decision) )

                                            if abs(off_target_start_1 -off_target_start_2 ) <100:
                                                print('___________________')
                                                print(possible_species)
                                                print(off_target_start_1, off_target_start_2)
    
    
    
    return()

# %%
# %%time

blast_search_targets(final)
# Out:
# start 1
# start blast
# end blast
# start 2
# start blast
# end blast
# start 3
# start blast
# end blast
# start 4
# start blast

# %%
list_of_cross_species
# Out:
# {'Borrelia afzelii',
#  'Borrelia burgdorferi',
#  'Borrelia garinii',
#  'Borrelia sp.',
#  'Borreliella afzelii',
#  'Borreliella bavariensis',
#  'Borreliella burgdorferi',
#  'Borreliella garinii',
#  'Borreliella valaisiana',
#  'Lachnoanaerobaculum umeaense',
#  'Paraglaciecola sp.',
#  'Pseudobutyrivibrio xylanivorans',
#  'Sporosarcina pasteurii',
#  'Virgibacillus sp.'}

# %% [markdown]
# # STANDALONE BLAST

# %%
from Bio import SeqIO
from Bio.Blast.Applications import NcbiblastpCommandline,NcbiblastnCommandline
from Bio.Blast import NCBIXML
from Bio.SeqRecord import SeqRecord
from Bio.Seq import Seq
import uuid,os,re

# %%
# %%time
list_of_fasta = []
for counter, value in enumerate(final['CjCas9_SaCas9_PAM-in'].keys()):
    pat_target_left = [*final['CjCas9_SaCas9_PAM-in'][value]['left']['afzelii'].values() ][0][:12]
    list_of_fasta.append(pat_target_left)

records = (SeqRecord(Seq(seq), str(index)) for index,seq in enumerate(list_of_fasta) )
SeqIO.write(records, 'targets_list.fasta', "fasta")
# Out:
# CPU times: user 1.82 ms, sys: 0 ns, total: 1.82 ms
# Wall time: 72 ms

# %%
# %%time

blastn_cline = NcbiblastnCommandline(query='targets_list.fasta',
                                            db='nt',
                                            outfmt=5,
                                            out='blast_result.xml',
                                            num_threads=20,
                                            word_size=11,
                                     evalue=1000, strand='both',
                                     template_type = 'coding', template_length = 18)
stdout, stderr = blastn_cline(env={'BLASTDB':'/home/_shared/nt_raw/'})
# Out:
# CPU times: user 2.67 ms, sys: 10 ms, total: 12.7 ms
# Wall time: 1min 46s

# %%
with open("blast_result.xml") as b:
    for record in NCBIXML.parse(b):
            record.alignments = record.alignments
            print('_______________________________________________________________________')
            for alignment in record.alignments:
                
                for hsp in alignment.hsps:
                    if hsp.expect < 1000:
                     #if hsp.gaps >0:
                        print("****Alignment****")
                        print("sequence:", alignment.title)
                        print("length:", alignment.length)
                        print("e value:", hsp.expect)
                        print(hsp.query )
                        print(hsp.match )
                        print(hsp.sbjct )
                        print(hsp.gaps)
                        print(hsp.positives)
            #print(hsp.score )
            #print(hsp.query_start )
            #print(hsp.sbjct_start )
            #print(hsp.strand )
            #a.append(hsp.gaps)
# Out:
# _______________________________________________________________________
# ****Alignment****
# sequence: gb|CP044535.1| Borrelia sp. CA690 chromosome, complete genome
# length: 902176
# e value: 0.250102
# GCTTTTTAACTATTTGATCTCT
# ||||||||||||||||||||||
# GCTTTTTAACTATTTGATCTCT
# 0
# 22
# ****Alignment****
# sequence: gb|CP028861.1| Borreliella garinii strain 20047 chromosome, complete genome
# length: 906449
# e value: 0.250102
# GCTTTTTAACTATTTGATCTCT
# ||||||||||||||||||||||
# GCTTTTTAACTATTTGATCTCT
# 0
# 22
# ****Alignment****
# sequence: gb|CP028872.1| Borreliella bavariensis PBi chromosome 1, complete sequence
# length: 905817
# e value: 0.250102
# GCTTTTTAACTATTTGATCTCT
# ||||||||||||||||||||||
# GCTTTTTAACTATTTGATCTCT
# 0
# 22
# ****Alignment****
# sequence: gb|CP031412.1| Borreliella burgdorferi strain MM1 chromosome main, complete sequence
# length: 908512
# e value: 0.250102
# GCTTTTTAACTATTTGATCTCT
# ||||||||||||||||||||||
# GCTTTTTAACTATTTGATCTCT
# 0
# 22
# ****Alignment****
# sequence: gb|CP017201.1| Borreliella burgdorferi strain B331 chromosome, complete genome
# length: 904573
# e value: 0.250102
# GCTTTTTAACTATTTGATCTCT
# ||||||||||||||||||||||
# GCTTTTTAACTATTTGATCTCT
# 0
# 22
# ****Alignment****
# sequence: gb|CP019767.1| Borrelia burgdorferi strain B31_NRZ, complete sequence
# length: 909921
# e value: 0.250102
# GCTTTTTAACTATTTGATCTCT
# ||||||||||||||||||||||
# GCTTTTTAACTATTTGATCTCT
# 0
# 22
# ****Alignment****
# sequence: gb|CP019916.1| Borreliella burgdorferi strain PAbe chromosome, complete genome
# length: 910728
# e value: 0.250102
# GCTTTTTAACTATTTGATCTCT
# ||||||||||||||||||||||
# GCTTTTTAACTATTTGATCTCT
# 0
# 22
# ****Alignment****
# sequence: gb|CP019844.1| Borreliella burgdorferi strain PAli, complete genome
# length: 909921
# e value: 0.250102
# GCTTTTTAACTATTTGATCTCT
# ||||||||||||||||||||||
# GCTTTTTAACTATTTGATCTCT
# 0
# 22
# ****Alignment****
# sequence: gb|CP015780.1| Borrelia mayonii strain MN14-1420, complete genome
# length: 904387
# e value: 0.250102
# GCTTTTTAACTATTTGATCTCT
# ||||||||||||||||||||||
# GCTTTTTAACTATTTGATCTCT
# 0
# 22
# ****Alignment****
# sequence: gb|CP015796.1| Borrelia mayonii strain MN14-1539 chromosome, complete genome
# length: 904387
# e value: 0.250102
# GCTTTTTAACTATTTGATCTCT
# ||||||||||||||||||||||
# GCTTTTTAACTATTTGATCTCT
# 0
# 22
# ****Alignment****
# sequence: gb|CP018744.1| Borreliella garinii strain CIP 103362 isolate 20047 chromosome, complete genome
# length: 905638
# e value: 0.250102
# GCTTTTTAACTATTTGATCTCT
# ||||||||||||||||||||||
# GCTTTTTAACTATTTGATCTCT
# 0
# 22
# ****Alignment****
# sequence: gb|CP018262.1| Borreliella afzelii strain BO23 chromosome, complete genome
# length: 905394
# e value: 0.250102
# GCTTTTTAACTATTTGATCTCT
# ||||||||||||||||||||||
# GCTTTTTAACTATTTGATCTCT
# 0
# 22
# ****Alignment****
# sequence: gb|CP009058.1| Borrelia afzelii K78, complete genome
# length: 905949
# e value: 0.250102
# GCTTTTTAACTATTTGATCTCT
# ||||||||||||||||||||||
# GCTTTTTAACTATTTGATCTCT
# 0
# 22
# ****Alignment****
# sequence: gb|CP009910.1| Borreliella chilensis strain VA1 chromosome, complete genome
# length: 900694
# e value: 0.250102
# GCTTTTTAACTATTTGATCTCT
# ||||||||||||||||||||||
# GCTTTTTAACTATTTGATCTCT
# 0
# 22
# ****Alignment****
# sequence: gb|CP009212.1| Borrelia afzelii Tom3107, complete genome
# length: 905861
# e value: 0.250102
# GCTTTTTAACTATTTGATCTCT
# ||||||||||||||||||||||
# GCTTTTTAACTATTTGATCTCT
# 0
# 22
# ****Alignment****
# sequence: gb|CP007564.1| Borrelia garinii SZ, complete genome
# length: 902487
# e value: 0.250102
# GCTTTTTAACTATTTGATCTCT
# ||||||||||||||||||||||
# GCTTTTTAACTATTTGATCTCT
# 0
# 22
# ****Alignment****
# sequence: gb|CP005925.1| Borrelia burgdorferi CA382, complete genome
# length: 910736
# e value: 0.250102
# GCTTTTTAACTATTTGATCTCT
# ||||||||||||||||||||||
# GCTTTTTAACTATTTGATCTCT
# 0
# 22
# ****Alignment****
# sequence: gb|CP003882.1| Borrelia afzelii HLJ01, complete genome
# length: 905471
# e value: 0.250102
# GCTTTTTAACTATTTGATCTCT
# ||||||||||||||||||||||
# GCTTTTTAACTATTTGATCTCT
# 0
# 22
# ****Alignment****
# sequence: gb|CP003866.1| Borrelia garinii NMJW1, complete genome
# length: 902789
# e value: 0.250102
# GCTTTTTAACTATTTGATCTCT
# ||||||||||||||||||||||
# GCTTTTTAACTATTTGATCTCT
# 0
# 22
# ****Alignment****
# sequence: gb|CP003151.1| Borrelia garinii BgVir chromosome linear, complete sequence
# length: 905534
# e value: 0.250102
# GCTTTTTAACTATTTGATCTCT
# ||||||||||||||||||||||
# GCTTTTTAACTATTTGATCTCT
# 0
# 22
# ****Alignment****
# sequence: gb|CP002933.1| Borrelia afzelii PKo, complete genome
# length: 903609
# e value: 0.250102
# GCTTTTTAACTATTTGATCTCT
# ||||||||||||||||||||||
# GCTTTTTAACTATTTGATCTCT
# 0
# 22
# ****Alignment****
# sequence: gb|CP002746.1| Borreliella bissettii DN127, complete genome
# length: 900755
# e value: 0.250102
# GCTTTTTAACTATTTGATCTCT
# ||||||||||||||||||||||
# GCTTTTTAACTATTTGATCTCT
# 0
# 22
# ****Alignment****
# sequence: gb|CP002228.1| Borrelia burgdorferi N40, complete genome
# length: 902191
# e value: 0.250102
# GCTTTTTAACTATTTGATCTCT
# ||||||||||||||||||||||
# GCTTTTTAACTATTTGATCTCT
# 0
# 22
# ****Alignment****
# sequence: gb|CP002312.1| Borrelia burgdorferi JD1, complete genome
# length: 922801
# e value: 0.250102
# GCTTTTTAACTATTTGATCTCT
# ||||||||||||||||||||||
# GCTTTTTAACTATTTGATCTCT
# 0
# 22
# ****Alignment****
# sequence: gb|CP001205.1| Borrelia burgdorferi ZS7, complete genome
# length: 906707
# e value: 0.250102
# GCTTTTTAACTATTTGATCTCT
# ||||||||||||||||||||||
# GCTTTTTAACTATTTGATCTCT
# 0
# 22
# ****Alignment****
# sequence: gb|CP000395.1| Borrelia afzelii PKo, complete genome
# length: 905394
# e value: 0.250102
# GCTTTTTAACTATTTGATCTCT
# ||||||||||||||||||||||
# GCTTTTTAACTATTTGATCTCT
# 0
# 22
# ****Alignment****
# sequence: gb|CP000013.1| Borreliella bavariensis PBi, complete genome
# length: 904246
# e value: 0.250102
# GCTTTTTAACTATTTGATCTCT
# ||||||||||||||||||||||
# GCTTTTTAACTATTTGATCTCT
# 0
# 22
# ****Alignment****
# sequence: gb|AE000783.1| Borrelia burgdorferi B31, complete genome
# length: 910724
# e value: 0.250102
# GCTTTTTAACTATTTGATCTCT
# ||||||||||||||||||||||
# GCTTTTTAACTATTTGATCTCT
# 0
# 22
# ****Alignment****
# sequence: gb|L32861.1| Borrelia burgdorferi 1-acyl-sn-glycerol-3-phosphate acetyltransferase (plsC) gene, 3' end; topoisomerase IV beta-subunit (parE) gene, 5' end
# length: 677
# e value: 0.250102
# GCTTTTTAACTATTTGATCTCT
# ||||||||||||||||||||||
# GCTTTTTAACTATTTGATCTCT
# 0
# 22
# ****Alignment****
# sequence: emb|LR738555.1| Neostethus bicornis genome assembly, chromosome: 14
# length: 27895003
# e value: 0.899526
# CTTTTTAACTATTTGATCTCT
# |||||||||||||||||||||
# CTTTTTAACTATTTGATCTCT
# 0
# 21
# ****Alignment****
# sequence: emb|LR812499.1| Danio aesculapii genome assembly, chromosome: 16
# length: 57624524
# e value: 11.6361
# TTTTAACTATTTGATCTCT
# |||||||||||||||||||
# TTTTAACTATTTGATCTCT
# 0
# 19
# ****Alignment****
# sequence: emb|LR812499.1| Danio aesculapii genome assembly, chromosome: 16
# length: 57624524
# e value: 41.8509
# GCTTTTTAACTATTTGAT
# ||||||||||||||||||
# GCTTTTTAACTATTTGAT
# 0
# 18
# ****Alignment****
# sequence: emb|LR812499.1| Danio aesculapii genome assembly, chromosome: 16
# length: 57624524
# e value: 150.522
# GCTTTTTAACTATTTGATCT
# |||||| |||||||||||||
# GCTTTTCAACTATTTGATCT
# 0
# 19
# ****Alignment****
# sequence: emb|LR812499.1| Danio aesculapii genome assembly, chromosome: 16
# length: 57624524
# e value: 541.375
# TTTAACTATTTGATCT
# ||||||||||||||||
# TTTAACTATTTGATCT
# 0
# 16
# ****Alignment****
# sequence: gb|CP050600.1| Canis lupus familiaris breed Labrador retriever chromosome 11a
# length: 73584800
# e value: 11.6361
# GCTTTTTAACTATTTGATCTCT
# ||||||| ||||||||||||||
# GCTTTTTGACTATTTGATCTCT
# 0
# 21
# ****Alignment****
# sequence: gb|CP050600.1| Canis lupus familiaris breed Labrador retriever chromosome 11a
# length: 73584800
# e value: 541.375
# GCTTTTTAACTATTTGATC
# |||||||| ||||||||||
# GCTTTTTATCTATTTGATC
# 0
# 18
# ****Alignment****
# sequence: gb|CP050588.1| Canis lupus familiaris breed Labrador retriever chromosome 24a
# length: 47610717
# e value: 11.6361
# TTTTTAACTATTTGATCTC
# |||||||||||||||||||
# TTTTTAACTATTTGATCTC
# 0
# 19
# ****Alignment****
# sequence: gb|CP050643.1| Canis lupus familiaris breed Labrador retriever chromosome 24b
# length: 47624915
# e value: 11.6361
# TTTTTAACTATTTGATCTC
# |||||||||||||||||||
# TTTTTAACTATTTGATCTC
# 0
# 19
# ****Alignment****
# sequence: gb|CP050630.1| Canis lupus familiaris breed Labrador retriever chromosome 11b
# length: 73564375
# e value: 11.6361
# GCTTTTTAACTATTTGATCTCT
# ||||||| ||||||||||||||
# GCTTTTTGACTATTTGATCTCT
# 0
# 21
# ****Alignment****
# sequence: gb|CP050630.1| Canis lupus familiaris breed Labrador retriever chromosome 11b
# length: 73564375
# e value: 541.375
# GCTTTTTAACTATTTGATC
# |||||||| ||||||||||
# GCTTTTTATCTATTTGATC
# 0
# 18
# ****Alignment****
# sequence: gb|CP049011.1| Saccharomyces pastorianus strain CBS 1483 chromosome SeXIV
# length: 765111
# e value: 11.6361
# GCTTTTTAACTATTTGATCTCT
# |||||||||| |||||||||||
# GCTTTTTAACAATTTGATCTCT
# 0
# 21
# ****Alignment****
# sequence: gb|CP042286.1| Staphylococcus argenteus strain B3-25B chromosome, complete genome
# length: 2676222
# e value: 11.6361
# CTTTTTAACTATTTGATCT
# |||||||||||||||||||
# CTTTTTAACTATTTGATCT
# 0
# 19
# ****Alignment****
# sequence: emb|LR597469.1| Sphaeramia orbicularis genome assembly, chromosome: 12
# length: 81199652
# e value: 11.6361
# TTTTAACTATTTGATCTCT
# |||||||||||||||||||
# TTTTAACTATTTGATCTCT
# 0
# 19
# ****Alignment****
# sequence: emb|LR597469.1| Sphaeramia orbicularis genome assembly, chromosome: 12
# length: 81199652
# e value: 150.522
# CTTTTTAACTATTTGAT
# |||||||||||||||||
# CTTTTTAACTATTTGAT
# 0
# 17
# ****Alignment****
# sequence: emb|LR597469.1| Sphaeramia orbicularis genome assembly, chromosome: 12
# length: 81199652
# e value: 150.522
# CTTTTTAACTATTTGAT
# |||||||||||||||||
# CTTTTTAACTATTTGAT
# 0
# 17
# ****Alignment****
# sequence: emb|LR597457.1| Salarias fasciatus genome assembly, chromosome: 23
# length: 41705463
# e value: 11.6361
# TTTTTAACTATTTGATCTC
# |||||||||||||||||||
# TTTTTAACTATTTGATCTC
# 0
# 19
# ****Alignment****
# sequence: emb|LR597457.1| Salarias fasciatus genome assembly, chromosome: 23
# length: 41705463
# e value: 41.8509
# CTTTTTAACTATTTGATCTCT
# ||||||||| |||||||||||
# CTTTTTAACCATTTGATCTCT
# 0
# 20
# ****Alignment****
# sequence: emb|LR594594.1| Syngnathus acus genome assembly, chromosome: 9
# length: 20014430
# e value: 11.6361
# GCTTTTTAACTATTTGATC
# |||||||||||||||||||
# GCTTTTTAACTATTTGATC
# 0
# 19
# ****Alignment****
# sequence: emb|LR134304.1| Staphylococcus schweitzeri strain NCTC13712 genome assembly, chromosome: 1
# length: 2784939
# e value: 11.6361
# CTTTTTAACTATTTGATCT
# |||||||||||||||||||
# CTTTTTAACTATTTGATCT
# 0
# 19
# ****Alignment****
# sequence: gb|CP030958.1| Saccharomyces eubayanus strain CBS12357 chromosome XIV, complete sequence
# length: 767356
# e value: 11.6361
# GCTTTTTAACTATTTGATCTCT
# |||||||||| |||||||||||
# GCTTTTTAACAATTTGATCTCT
# 0
# 21
# ****Alignment****
# sequence: ref|XM_016099143.2| PREDICTED: Arachis duranensis Werner Syndrome-like exonuclease (LOC107478989), mRNA
# length: 947
# e value: 11.6361
# CTTTTTAACTATTTGATCT
# |||||||||||||||||||
# CTTTTTAACTATTTGATCT
# 0
# 19
# ****Alignment****
# sequence: gb|CP015758.1| Staphylococcus argenteus strain BN75 genome
# length: 2754198
# e value: 11.6361
# CTTTTTAACTATTTGATCT
# |||||||||||||||||||
# CTTTTTAACTATTTGATCT
# 0
# 19
# ****Alignment****
# sequence: ref|XM_018367515.1| Saccharomyces eubayanus RTC4-like protein (DI49_4493), partial mRNA
# length: 1206
# e value: 11.6361
# GCTTTTTAACTATTTGATCTCT
# |||||||||| |||||||||||
# GCTTTTTAACAATTTGATCTCT
# 0
# 21
# ****Alignment****
# sequence: emb|LK067121.1| Apteryx australis mantelli genome assembly AptMant0, scaffold scaffold773
# length: 4578139
# e value: 11.6361
# TTTTAACTATTTGATCTCT
# |||||||||||||||||||
# TTTTAACTATTTGATCTCT
# 0
# 19
# ****Alignment****
# sequence: emb|LN713264.1| Cucumis melo genomic chromosome, chr_10
# length: 25362315
# e value: 11.6361
# TTTTAACTATTTGATCTCT
# |||||||||||||||||||
# TTTTAACTATTTGATCTCT
# 0
# 19
# ****Alignment****
# sequence: emb|LN713264.1| Cucumis melo genomic chromosome, chr_10
# length: 25362315
# e value: 541.375
# TTTTTAACTATTTGATCTC
# ||||||| |||||||||||
# TTTTTAATTATTTGATCTC
# 0
# 18
# ****Alignment****
# sequence: emb|LN713264.1| Cucumis melo genomic chromosome, chr_10
# length: 25362315
# e value: 541.375
# TTTTTAACTATTTGATCTC
# ||||||| |||||||||||
# TTTTTAATTATTTGATCTC
# 0
# 18
# ****Alignment****
# sequence: emb|LN713264.1| Cucumis melo genomic chromosome, chr_10
# length: 25362315
# e value: 541.375
# TTTTTAACTATTTGAT
# ||||||||||||||||
# TTTTTAACTATTTGAT
# 0
# 16
# ****Alignment****
# sequence: emb|LN681896.1| Cucumis melo genomic scaffold, anchoredscaffold00016
# length: 5666009
# e value: 11.6361
# TTTTAACTATTTGATCTCT
# |||||||||||||||||||
# TTTTAACTATTTGATCTCT
# 0
# 19
# ****Alignment****
# sequence: emb|LM525561.1| Strongyloides papillosus genome assembly S_papillosus_LIN ,scaffold SPAL_scaffold0000006
# length: 725563
# e value: 11.6361
# CTTTTTAACTATTTGATCT
# |||||||||||||||||||
# CTTTTTAACTATTTGATCT
# 0
# 19
# ****Alignment****
# sequence: emb|FR821777.2| Staphylococcus argenteus MSHR1132 complete genome sequence
# length: 2762785
# e value: 11.6361
# CTTTTTAACTATTTGATCT
# |||||||||||||||||||
# CTTTTTAACTATTTGATCT
# 0
# 19
# ****Alignment****
# sequence: MK896634.1 Bakau virus segment M, complete sequence
# length: 4485
# e value: 11.6361
# CTTTTTAACTATTTGATCT
# |||||||||||||||||||
# CTTTTTAACTATTTGATCT
# 0
# 19
# ****Alignment****
# sequence: emb|LR812534.1| Danio kyathit genome assembly, chromosome: 16
# length: 72833698
# e value: 11.6361
# TTTTAACTATTTGATCTCT
# |||||||||||||||||||
# TTTTAACTATTTGATCTCT
# 0
# 19
# ****Alignment****
# sequence: emb|LR812534.1| Danio kyathit genome assembly, chromosome: 16
# length: 72833698
# e value: 150.522
# CTTTTTAACTATTTGAT
# |||||||||||||||||
# CTTTTTAACTATTTGAT
# 0
# 17
# ****Alignment****
# sequence: emb|LR812534.1| Danio kyathit genome assembly, chromosome: 16
# length: 72833698
# e value: 150.522
# CTTTTTAACTATTTGATCTC
# ||||||||| ||||||||||
# CTTTTTAACAATTTGATCTC
# 0
# 19
# ****Alignment****
# sequence: emb|LR812534.1| Danio kyathit genome assembly, chromosome: 16
# length: 72833698
# e value: 541.375
# GCTTTTTAACTATTTGATC
# |||||||||||||| ||||
# GCTTTTTAACTATTAGATC
# 0
# 18
# ****Alignment****
# sequence: gb|AC110538.6| Mus musculus chromosome 5, clone RP23-71L23, complete sequence
# length: 205923
# e value: 11.6361
# GCTTTTTAACTATTTGATCTCT
# |||||| |||||||||||||||
# GCTTTTGAACTATTTGATCTCT
# 0
# 21
# ****Alignment****
# sequence: gb|AC160551.4| Mus musculus chromosome 5, clone RP23-296C20, complete sequence
# length: 173331
# e value: 11.6361
# GCTTTTTAACTATTTGATCTCT
# |||||| |||||||||||||||
# GCTTTTGAACTATTTGATCTCT
# 0
# 21
# ****Alignment****
# sequence: dbj|AP019866.1| Marchantia polymorpha subsp. ruderalis Tak-1 DNA, chromosome: 1
# length: 30584173
# e value: 41.8509
# TTTTTAACTATTTGATCT
# ||||||||||||||||||
# TTTTTAACTATTTGATCT
# 0
# 18
# ****Alignment****
# sequence: dbj|AP023162.1| Felis catus Senzu DNA, chromosome: D2, American Shorthair breed
# length: 90643714
# e value: 41.8509
# CTTTTTAACTATTTGATCTCT
# |||||||||| ||||||||||
# CTTTTTAACTTTTTGATCTCT
# 0
# 20
# ****Alignment****
# sequence: gb|CP050236.1| Morus alba cultivar Heyebai chromosome 13
# length: 17184522
# e value: 41.8509
# TTTTTAACTATTTGATCT
# ||||||||||||||||||
# TTTTTAACTATTTGATCT
# 0
# 18
# ****Alignment****
# sequence: gb|CP050591.1| Canis lupus familiaris breed Labrador retriever chromosome 10a
# length: 69938001
# e value: 41.8509
# CTTTTTAACTATTTGATCTCT
# |||||||||||||| ||||||
# CTTTTTAACTATTTAATCTCT
# 0
# 20
# ****Alignment****
# sequence: gb|CP050611.1| Canis lupus familiaris breed Labrador retriever chromosome 10b
# length: 69942321
# e value: 41.8509
# CTTTTTAACTATTTGATCTCT
# |||||||||||||| ||||||
# CTTTTTAACTATTTAATCTCT
# 0
# 20
# ****Alignment****
# sequence: emb|LR778312.1| Raphanus sativus genome assembly, chromosome: 3
# length: 45313491
# e value: 41.8509
# TTTTTAACTATTTGATCT
# ||||||||||||||||||
# TTTTTAACTATTTGATCT
# 0
# 18
# ****Alignment****
# sequence: emb|LR778276.1| Coregonus sp. 'balchen' genome assembly, chromosome: 24
# length: 50329371
# e value: 41.8509
# GCTTTTTAACTATTTGAT
# ||||||||||||||||||
# GCTTTTTAACTATTTGAT
# 0
# 18
# ****Alignment****
# sequence: emb|LR778276.1| Coregonus sp. 'balchen' genome assembly, chromosome: 24
# length: 50329371
# e value: 541.375
# GCTTTTTAACTATTTG
# ||||||||||||||||
# GCTTTTTAACTATTTG
# 0
# 16
# ****Alignment****
# sequence: gb|CP049223.1| Lactobacillus iners strain C0094A1 chromosome, complete genome
# length: 1379823
# e value: 41.8509
# GCTTTTTAACTATTTGAT
# ||||||||||||||||||
# GCTTTTTAACTATTTGAT
# 0
# 18
# ****Alignment****
# sequence: gb|CP049225.1| Lactobacillus iners strain C0059G1 chromosome, complete genome
# length: 1379123
# e value: 41.8509
# GCTTTTTAACTATTTGAT
# ||||||||||||||||||
# GCTTTTTAACTATTTGAT
# 0
# 18
# ****Alignment****
# sequence: gb|CP049226.1| Lactobacillus iners strain C0011D1 chromosome, complete genome
# length: 1398354
# e value: 41.8509
# GCTTTTTAACTATTTGAT
# ||||||||||||||||||
# GCTTTTTAACTATTTGAT
# 0
# 18
# ****Alignment****
# sequence: gb|CP049228.1| Lactobacillus iners strain C0210C1 chromosome, complete genome
# length: 1395649
# e value: 41.8509
# GCTTTTTAACTATTTGAT
# ||||||||||||||||||
# GCTTTTTAACTATTTGAT
# 0
# 18
# ****Alignment****
# sequence: gb|CP049230.1| Lactobacillus iners strain C0322A1 chromosome, complete genome
# length: 1318700
# e value: 41.8509
# GCTTTTTAACTATTTGAT
# ||||||||||||||||||
# GCTTTTTAACTATTTGAT
# 0
# 18
# ****Alignment****
# sequence: gb|CP049231.1| Lactobacillus iners strain C0254C1 chromosome, complete genome
# length: 1314822
# e value: 41.8509
# GCTTTTTAACTATTTGAT
# ||||||||||||||||||
# GCTTTTTAACTATTTGAT
# 0
# 18
# ****Alignment****
# sequence: gb|CP048848.1| Crassostrea gigas strain QD chromosome 10
# length: 38615286
# e value: 41.8509
# GCTTTTTAACTATTTGATCTC
# |||| ||||||||||||||||
# GCTTCTTAACTATTTGATCTC
# 0
# 20
# ****Alignment****
# sequence: gb|CP048848.1| Crassostrea gigas strain QD chromosome 10
# length: 38615286
# e value: 150.522
# TTTTAACTATTTGATCT
# |||||||||||||||||
# TTTTAACTATTTGATCT
# 0
# 17
# ****Alignment****
# sequence: gb|CP048798.1| Lactobacillus iners strain KY chromosome, complete genome
# length: 1339101
# e value: 41.8509
# GCTTTTTAACTATTTGAT
# ||||||||||||||||||
# GCTTTTTAACTATTTGAT
# 0
# 18
# ****Alignment****
# sequence: gb|CP047566.1| Solanum pinnatisectum cultivar CGN17745 chromosome 3
# length: 62237402
# e value: 41.8509
# CTTTTTAACTATTTGATC
# ||||||||||||||||||
# CTTTTTAACTATTTGATC
# 0
# 18
# ****Alignment****
# sequence: gb|CP047560.1| Solanum pinnatisectum cultivar CGN17745 chromosome 9
# length: 61517478
# e value: 41.8509
# CTTTTTAACTATTTGATC
# ||||||||||||||||||
# CTTTTTAACTATTTGATC
# 0
# 18
# ****Alignment****
# sequence: emb|LR738417.1| Lutra lutra genome assembly, chromosome: 15
# length: 69992071
# e value: 41.8509
# TTTTTAACTATTTGATCT
# ||||||||||||||||||
# TTTTTAACTATTTGATCT
# 0
# 18
# ****Alignment****
# sequence: emb|LR738417.1| Lutra lutra genome assembly, chromosome: 15
# length: 69992071
# e value: 150.522
# GCTTTTTAACTATTTGATCT
# ||||||||||||||| ||||
# GCTTTTTAACTATTTTATCT
# 0
# 19
# ****Alignment****
# sequence: emb|LR738417.1| Lutra lutra genome assembly, chromosome: 15
# length: 69992071
# e value: 150.522
# TTTTTAACTATTTGATCTCT
# ||||||||||||||| ||||
# TTTTTAACTATTTGAACTCT
# 0
# 19
# ****Alignment****
# sequence: emb|LR738417.1| Lutra lutra genome assembly, chromosome: 15
# length: 69992071
# e value: 541.375
# CTTTTTAACTATTTGATCT
# |||||||||||||| ||||
# CTTTTTAACTATTTTATCT
# 0
# 18
# ****Alignment****
# sequence: emb|LR738415.1| Lutra lutra genome assembly, chromosome: 13
# length: 95726014
# e value: 41.8509
# GCTTTTTAACTATTTGATCTCT
# ||||||| ||||||||||||||
# GCTTTTT-ACTATTTGATCTCT
# 1
# 21
# ****Alignment****
# sequence: MN693730.1 Marine virus AFVG_250M748, complete genome
# length: 57814
# e value: 41.8509
# TTTTTAACTATTTGATCT
# ||||||||||||||||||
# TTTTTAACTATTTGATCT
# 0
# 18
# ****Alignment****
# sequence: gb|CP046682.1| Solanum tuberosum cultivar P8 chromosome 3
# length: 62267263
# e value: 41.8509
# CTTTTTAACTATTTGATC
# ||||||||||||||||||
# CTTTTTAACTATTTGATC
# 0
# 18
# ****Alignment****
# sequence: gb|CP046693.1| Solanum tuberosum cultivar MSH/14-112 chromosome 9
# length: 61538434
# e value: 41.8509
# CTTTTTAACTATTTGATC
# ||||||||||||||||||
# CTTTTTAACTATTTGATC
# 0
# 18
# ****Alignment****
# sequence: emb|LR738542.1| Neostethus bicornis genome assembly, chromosome: 1
# length: 36095363
# e value: 41.8509
# CTTTTTAACTATTTGATCTCT
# |||||||||||||| ||||||
# CTTTTTAACTATTTAATCTCT
# 0
# 20
# ****Alignment****
# sequence: emb|LR738542.1| Neostethus bicornis genome assembly, chromosome: 1
# length: 36095363
# e value: 541.375
# TTTTTAACTATTTGAT
# ||||||||||||||||
# TTTTTAACTATTTGAT
# 0
# 16
# ****Alignment****
# sequence: gb|CP045799.1| Pseudomonas syringae USA011 chromosome, complete genome
# length: 6024796
# e value: 41.8509
# TTTTTAACTATTTGATCT
# ||||||||||||||||||
# TTTTTAACTATTTGATCT
# 0
# 18
# ****Alignment****
# sequence: gb|CP045664.1| Lactobacillus iners strain LI335 chromosome
# length: 1363099
# e value: 41.8509
# GCTTTTTAACTATTTGAT
# ||||||||||||||||||
# GCTTTTTAACTATTTGAT
# 0
# 18
# ****Alignment****
# sequence: ref|XM_031266607.1| PREDICTED: Ipomoea triloba pyrophosphate-energized membrane proton pump 3 (LOC116025378), transcript variant X2, mRNA
# length: 3403
# e value: 41.8509
# TTTTTAACTATTTGATCT
# ||||||||||||||||||
# TTTTTAACTATTTGATCT
# 0
# 18
# ****Alignment****
# sequence: ref|XM_031266599.1| PREDICTED: Ipomoea triloba pyrophosphate-energized membrane proton pump 3 (LOC116025378), transcript variant X1, mRNA
# length: 3386
# e value: 41.8509
# TTTTTAACTATTTGATCT
# ||||||||||||||||||
# TTTTTAACTATTTGATCT
# 0
# 18
# ****Alignment****
# sequence: emb|LR701162.1| Plasmodium knowlesi strain H genome assembly, chromosome: 2 >emb|AM910984.2| Plasmodium knowlesi strain H genome assembly, chromosome: 2
# length: 728134
# e value: 41.8509
# CTTTTTAACTATTTGATC
# ||||||||||||||||||
# CTTTTTAACTATTTGATC
# 0
# 18
# ****Alignment****
# sequence: gb|CP032577.1| Gossypium turneri isolate D10-2 chromosome D10_07
# length: 53747549
# e value: 41.8509
# TTTTTAACTATTTGATCT
# ||||||||||||||||||
# TTTTTAACTATTTGATCT
# 0
# 18
# ****Alignment****
# sequence: emb|LR697115.1| Chanos chanos genome assembly, chromosome: 10
# length: 40347274
# e value: 41.8509
# TTTTTAACTATTTGATCT
# ||||||||||||||||||
# TTTTTAACTATTTGATCT
# 0
# 18
# ****Alignment****
# sequence: emb|LR697115.1| Chanos chanos genome assembly, chromosome: 10
# length: 40347274
# e value: 150.522
# GCTTTTTAACTATTTGATCT
# ||||||| ||||||||||||
# GCTTTTTGACTATTTGATCT
# 0
# 19
# ****Alignment****
# sequence: emb|LR606201.1| Aquila chrysaetos chrysaetos genome assembly, chromosome: 21
# length: 24756580
# e value: 41.8509
# TTTTTAACTATTTGATCT
# ||||||||||||||||||
# TTTTTAACTATTTGATCT
# 0
# 18
# ****Alignment****
# sequence: gb|CP039337.1| Cicer arietinum chromosome Ca7
# length: 48961537
# e value: 41.8509
# TTTTTAACTATTTGATCT
# ||||||||||||||||||
# TTTTTAACTATTTGATCT
# 0
# 18
# ****Alignment****
# sequence: gb|CP039337.1| Cicer arietinum chromosome Ca7
# length: 48961537
# e value: 541.375
# TTTTTAACTATTTGAT
# ||||||||||||||||
# TTTTTAACTATTTGAT
# 0
# 16
# ****Alignment****
# sequence: gb|CP039337.1| Cicer arietinum chromosome Ca7
# length: 48961537
# e value: 541.375
# TTT-TTAACTATTTGATCTC
# ||| ||||||||||||||||
# TTTATTAACTATTTGATCTC
# 1
# 19
# ****Alignment****
# sequence: gb|CP039337.1| Cicer arietinum chromosome Ca7
# length: 48961537
# e value: 541.375
# TTT-TTAACTATTTGATCTC
# ||| ||||||||||||||||
# TTTATTAACTATTTGATCTC
# 1
# 19
# ****Alignment****
# sequence: gb|CP039336.1| Cicer arietinum chromosome Ca6
# length: 59463894
# e value: 41.8509
# TTTTTAACTATTTGATCT
# ||||||||||||||||||
# TTTTTAACTATTTGATCT
# 0
# 18
# ****Alignment****
# sequence: gb|CP040772.1| Cicer arietinum chromosome Ca7
# length: 48961553
# e value: 41.8509
# TTTTTAACTATTTGATCT
# ||||||||||||||||||
# TTTTTAACTATTTGATCT
# 0
# 18
# ****Alignment****
# sequence: gb|CP040772.1| Cicer arietinum chromosome Ca7
# length: 48961553
# e value: 541.375
# TTTTTAACTATTTGAT
# ||||||||||||||||
# TTTTTAACTATTTGAT
# 0
# 16
# ****Alignment****
# sequence: gb|CP040772.1| Cicer arietinum chromosome Ca7
# length: 48961553
# e value: 541.375
# TTT-TTAACTATTTGATCTC
# ||| ||||||||||||||||
# TTTATTAACTATTTGATCTC
# 1
# 19
# ****Alignment****
# sequence: gb|CP040772.1| Cicer arietinum chromosome Ca7
# length: 48961553
# e value: 541.375
# TTT-TTAACTATTTGATCTC
# ||| ||||||||||||||||
# TTTATTAACTATTTGATCTC
# 1
# 19
# ****Alignment****
# sequence: gb|CP040771.1| Cicer arietinum chromosome Ca6
# length: 59463883
# e value: 41.8509
# TTTTTAACTATTTGATCT
# ||||||||||||||||||
# TTTTTAACTATTTGATCT
# 0
# 18
# ****Alignment****
# sequence: dbj|LC165687.1| Drosophila fuyamai Cyt-c1 gene, partial cds, strain: CM77l
# length: 1050
# e value: 41.8509
# GCTTTTTAACTATTTGAT
# ||||||||||||||||||
# GCTTTTTAACTATTTGAT
# 0
# 18
# ****Alignment****
# sequence: gb|CP032248.1| Gossypioides kirkii chromosome KI_06
# length: 60359545
# e value: 41.8509
# TTTTTAACTATTTGATCT
# ||||||||||||||||||
# TTTTTAACTATTTGATCT
# 0
# 18
# ****Alignment****
# sequence: gb|CP032248.1| Gossypioides kirkii chromosome KI_06
# length: 60359545
# e value: 541.375
# GCT-TTTTAACTATTTGATCTCT
# ||| ||||||| |||||||||||
# GCTATTTTAACCATTTGATCTCT
# 1
# 21
# ****Alignment****
# sequence: gb|CP032248.1| Gossypioides kirkii chromosome KI_06
# length: 60359545
# e value: 541.375
# TTTTTAACTATTTGATCTCT
# |||||||||||||||| |||
# TTTTTAACTATTTGAT-TCT
# 1
# 19
# ****Alignment****
# sequence: gb|CP032248.1| Gossypioides kirkii chromosome KI_06
# length: 60359545
# e value: 541.375
# TTTTTAACTATTTGATCTC
# ||||||| |||||||||||
# TTTTTAATTATTTGATCTC
# 0
# 18
# ****Alignment****
# sequence: gb|CP032248.1| Gossypioides kirkii chromosome KI_06
# length: 60359545
# e value: 541.375
# TTTTTAACTATTTGATCTCT
# |||||||||||||||| |||
# TTTTTAACTATTTGAT-TCT
# 1
# 19
# ****Alignment****
# sequence: gb|CP032248.1| Gossypioides kirkii chromosome KI_06
# length: 60359545
# e value: 541.375
# TTTTTAACTATTTGATCTC
# ||||||||||||| |||||
# TTTTTAACTATTTCATCTC
# 0
# 18
# ****Alignment****
# sequence: gb|CP032245.1| Gossypioides kirkii chromosome KI_2_4
# length: 41238926
# e value: 41.8509
# CTTTTTAACTATTTGATCTCT
# |||||||||| ||||||||||
# CTTTTTAACTTTTTGATCTCT
# 0
# 20
# ****Alignment****
# sequence: gb|CP032245.1| Gossypioides kirkii chromosome KI_2_4
# length: 41238926
# e value: 541.375
# TAACTATTTGATCTCT
# ||||||||||||||||
# TAACTATTTGATCTCT
# 0
# 16
# ****Alignment****
# sequence: emb|LR535837.1| Mastacembelus armatus genome assembly, chromosome: 5
# length: 28762963
# e value: 41.8509
# GCTTTTTAACTATTTGAT
# ||||||||||||||||||
# GCTTTTTAACTATTTGAT
# 0
# 18
# ****Alignment****
# sequence: emb|LR535818.1| Denticeps clupeoides genome assembly, chromosome: 6
# length: 25515720
# e value: 41.8509
# TTTTTAACTATTTGATCT
# ||||||||||||||||||
# TTTTTAACTATTTGATCT
# 0
# 18
# ****Alignment****
# sequence: emb|LR132046.1| Anabas testudineus genome assembly, chromosome: 8
# length: 21832553
# e value: 41.8509
# TTTTTAACTATTTGATCT
# ||||||||||||||||||
# TTTTTAACTATTTGATCT
# 0
# 18
# ****Alignment****
# sequence: emb|LR132000.1| Gouania willdenowi genome assembly, chromosome: 6
# length: 72451976
# e value: 41.8509
# GCTTTTTAACTATTTGATCTC
# ||||||||| |||||||||||
# GCTTTTTAAATATTTGATCTC
# 0
# 20
# ****Alignment****
# sequence: emb|LR131990.1| Gouania willdenowi genome assembly, chromosome: 20
# length: 28787763
# e value: 41.8509
# GCTTTTTAACTATTTGAT
# ||||||||||||||||||
# GCTTTTTAACTATTTGAT
# 0
# 18
# ****Alignment****
# sequence: emb|LR131922.1| Cottoperca gobio genome assembly, chromosome: 15
# length: 24963210
# e value: 41.8509
# GCTTTTTAACTATTTGAT
# ||||||||||||||||||
# GCTTTTTAACTATTTGAT
# 0
# 18
# ****Alignment****
# sequence: gb|CP033077.1| Vibrio sp. HBUAS61001 chromosome 1, complete sequence
# length: 1107930
# e value: 41.8509
# CTTTTTAACTATTTGATCTCT
# ||||||||||||||||| |||
# CTTTTTAACTATTTGATATCT
# 0
# 20
# ****Alignment****
# sequence: MG712775.1 Fowl adenovirus 8b isolate SD1356, complete genome
# length: 44454
# e value: 41.8509
# GCTTTTTAACTATTTGAT
# ||||||||||||||||||
# GCTTTTTAACTATTTGAT
# 0
# 18
# ****Alignment****
# sequence: gb|CP025660.1| Ipomoea triloba cultivar NCNSP0323 chromosome 1
# length: 38093535
# e value: 41.8509
# CTTTTTAACTATTTGATCTCT
# |||||||||||||| ||||||
# CTTTTTAACTATTTTATCTCT
# 0
# 20
# ****Alignment****
# sequence: gb|CP025660.1| Ipomoea triloba cultivar NCNSP0323 chromosome 1
# length: 38093535
# e value: 41.8509
# TTTTTAACTATTTGATCT
# ||||||||||||||||||
# TTTTTAACTATTTGATCT
# 0
# 18
# ****Alignment****
# sequence: gb|CP025660.1| Ipomoea triloba cultivar NCNSP0323 chromosome 1
# length: 38093535
# e value: 541.375
# GCTTTTTAACTATTTGATC
# || ||||||||||||||||
# GCATTTTAACTATTTGATC
# 0
# 18
# ****Alignment****
# sequence: gb|CP025644.1| Ipomoea trifida cultivar NCNSP0306 chromosome 1
# length: 32247286
# e value: 41.8509
# TTTTTAACTATTTGATCT
# ||||||||||||||||||
# TTTTTAACTATTTGATCT
# 0
# 18
# ****Alignment****
# sequence: gb|CP035758.1| Ktedonosporobacter rubrisoli strain SCAWS-G2 chromosome, complete genome
# length: 11340617
# e value: 41.8509
# CTTTTTAACTATTTGATC
# ||||||||||||||||||
# CTTTTTAACTATTTGATC
# 0
# 18
# ****Alignment****
# sequence: gb|CP032584.1| Lateolabrax maculatus linkage group 1 sequence
# length: 31475329
# e value: 41.8509
# CTTTTTAACTATTTGATC
# ||||||||||||||||||
# CTTTTTAACTATTTGATC
# 0
# 18
# ****Alignment****
# sequence: gb|CP027284.1| Lateolabrax maculatus chromosome Lm23
# length: 28603024
# e value: 41.8509
# CTTTTTAACTATTTGATC
# ||||||||||||||||||
# CTTTTTAACTATTTGATC
# 0
# 18
# ****Alignment****
# sequence: ref|NG_011805.2| Homo sapiens erb-b2 receptor tyrosine kinase 4 (ERBB4), RefSeqGene on chromosome 2
# length: 1169912
# e value: 41.8509
# CTTTTTAACTATTTGATCTCT
# |||||||||||||| ||||||
# CTTTTTAACTATTTTATCTCT
# 0
# 20
# ****Alignment****
# sequence: MF577036.1 Fowl adenovirus 8b isolate QD2016, complete genome
# length: 43632
# e value: 41.8509
# GCTTTTTAACTATTTGAT
# ||||||||||||||||||
# GCTTTTTAACTATTTGAT
# 0
# 18
# ****Alignment****
# sequence: ref|XM_025057193.1| PREDICTED: Cynoglossus semilaevis leucine rich repeat containing G protein-coupled receptor 5 (lgr5), partial mRNA
# length: 3934
# e value: 41.8509
# TTTTTAACTATTTGATCT
# ||||||||||||||||||
# TTTTTAACTATTTGATCT
# 0
# 18
# ****Alignment****
# sequence: gb|CP027095.1| Bos mutus isolate yakQH1 chromosome 27
# length: 43292763
# e value: 41.8509
# CTTTTTAACTATTTGATC
# ||||||||||||||||||
# CTTTTTAACTATTTGATC
# 0
# 18
# ****Alignment****
# sequence: gb|CP027080.1| Bos mutus isolate yakQH1 chromosome 12
# length: 78435519
# e value: 41.8509
# TTTTTAACTATTTGATCT
# ||||||||||||||||||
# TTTTTAACTATTTGATCT
# 0
# 18
# ****Alignment****
# sequence: gb|CP027080.1| Bos mutus isolate yakQH1 chromosome 12
# length: 78435519
# e value: 541.375
# TTTTTAACTATTTGAT
# ||||||||||||||||
# TTTTTAACTATTTGAT
# 0
# 16
# ****Alignment****
# sequence: gb|CP022344.1| Chromobacterium vaccinii strain XC0014 chromosome, complete genome
# length: 4939655
# e value: 41.8509
# GCTTTTTAACTATTTGAT
# ||||||||||||||||||
# GCTTTTTAACTATTTGAT
# 0
# 18
# ****Alignment****
# sequence: ref|XM_023884978.1| PREDICTED: Lactuca sativa trichohyalin (LOC111888852), transcript variant X5, mRNA
# length: 3077
# e value: 41.8509
# CTTTTTAACTATTTGATCTCT
# |||||||||| ||||||||||
# CTTTTTAACTCTTTGATCTCT
# 0
# 20
# ****Alignment****
# sequence: ref|XM_023884977.1| PREDICTED: Lactuca sativa trichohyalin (LOC111888852), transcript variant X4, mRNA
# length: 3376
# e value: 41.8509
# CTTTTTAACTATTTGATCTCT
# |||||||||| ||||||||||
# CTTTTTAACTCTTTGATCTCT
# 0
# 20
# ****Alignment****
# sequence: ref|XM_023884976.1| PREDICTED: Lactuca sativa trichohyalin (LOC111888852), transcript variant X3, mRNA
# length: 2427
# e value: 41.8509
# CTTTTTAACTATTTGATCTCT
# |||||||||| ||||||||||
# CTTTTTAACTCTTTGATCTCT
# 0
# 20
# ****Alignment****
# sequence: ref|XM_023884975.1| PREDICTED: Lactuca sativa trichohyalin (LOC111888852), transcript variant X2, mRNA
# length: 3076
# e value: 41.8509
# CTTTTTAACTATTTGATCTCT
# |||||||||| ||||||||||
# CTTTTTAACTCTTTGATCTCT
# 0
# 20
# ****Alignment****
# sequence: ref|XM_023884973.1| PREDICTED: Lactuca sativa trichohyalin (LOC111888852), transcript variant X1, mRNA
# length: 3395
# e value: 41.8509
# CTTTTTAACTATTTGATCTCT
# |||||||||| ||||||||||
# CTTTTTAACTCTTTGATCTCT
# 0
# 20
# ****Alignment****
# sequence: emb|LT727649.1| Plasmodium knowlesi genome assembly, chromosome: PkA1H1_02_v1
# length: 787547
# e value: 41.8509
# CTTTTTAACTATTTGATC
# ||||||||||||||||||
# CTTTTTAACTATTTGATC
# 0
# 18
# ****Alignment****
# sequence: gb|CP023118.1| Lupinus angustifolius cultivar Tanjil chromosome LG-06
# length: 40902325
# e value: 41.8509
# TTTAACTATTTGATCTCT
# ||||||||||||||||||
# TTTAACTATTTGATCTCT
# 0
# 18
# ****Alignment****
# sequence: ref|XM_022264237.1| PREDICTED: Pieris rapae uncharacterized LOC110996515 (LOC110996515), mRNA
# length: 2157
# e value: 41.8509
# CTTTTTAACTATTTGATCTCT
# |||||| ||||||||||||||
# CTTTTTCACTATTTGATCTCT
# 0
# 20
# ****Alignment****
# sequence: ref|XM_022275012.1| PREDICTED: Pieris rapae uncharacterized monothiol glutaredoxin ycf64-like (LOC111004141), mRNA
# length: 897
# e value: 41.8509
# TTTTTAACTATTTGATCT
# ||||||||||||||||||
# TTTTTAACTATTTGATCT
# 0
# 18
# ****Alignment****
# sequence: gb|CP020782.1| Oryzias latipes strain HNI chromosome 4
# length: 31648822
# e value: 41.8509
# TTTTTAACTATTTGATCT
# ||||||||||||||||||
# TTTTTAACTATTTGATCT
# 0
# 18
# ****Alignment****
# sequence: ref|XM_021968504.1| PREDICTED: Prunus avium uncharacterized LOC110765384 (LOC110765384), mRNA
# length: 925
# e value: 41.8509
# CTTTTTAACTATTTGATC
# ||||||||||||||||||
# CTTTTTAACTATTTGATC
# 0
# 18
# ****Alignment****
# sequence: ref|XM_021853297.1| PREDICTED: Aedes aegypti uncharacterized LOC5577785 (LOC5577785), transcript variant X2, mRNA
# length: 2857
# e value: 41.8509
# CTTTTTAACTATTTGATCTCT
# |||| ||||||||||||||||
# CTTTATAACTATTTGATCTCT
# 0
# 20
# ****Alignment****
# sequence: ref|XM_001663508.2| PREDICTED: Aedes aegypti uncharacterized LOC5577785 (LOC5577785), transcript variant X1, mRNA
# length: 3644
# e value: 41.8509
# CTTTTTAACTATTTGATCTCT
# |||| ||||||||||||||||
# CTTTATAACTATTTGATCTCT
# 0
# 20
# ****Alignment****
# sequence: gb|CP018163.1| Oryza sativa Indica Group cultivar Shuhui498 chromosome 7 sequence
# length: 30277827
# e value: 41.8509
# TTTTTAACTATTTGATCT
# ||||||||||||||||||
# TTTTTAACTATTTGATCT
# 0
# 18
# ****Alignment****
# sequence: gb|CP019098.1| Spirodela polyrhiza strain 9509 chromosome 6 sequence
# length: 8045491
# e value: 41.8509
# CTTTTTAACTATTTGATCTCT
# ||||||||| |||||||||||
# CTTTTTAACAATTTGATCTCT
# 0
# 20
# ****Alignment****
# sequence: emb|LT669790.1| Arabis alpina genome assembly, chromosome: 3
# length: 30422129
# e value: 41.8509
# TTTTTAACTATTTGATCT
# ||||||||||||||||||
# TTTTTAACTATTTGATCT
# 0
# 18
# ****Alignment****
# sequence: emb|LT669790.1| Arabis alpina genome assembly, chromosome: 3
# length: 30422129
# e value: 150.522
# TTTTTAACTATTTGATCTCT
# ||||||||||||||| ||||
# TTTTTAACTATTTGAACTCT
# 0
# 19
# ****Alignment****
# sequence: gb|CP017770.1| Paenibacillus crassostreae strain LPB0068 chromosome, complete genome
# length: 4627176
# e value: 41.8509
# TTTTTAACTATTTGATCT
# ||||||||||||||||||
# TTTTTAACTATTTGATCT
# 0
# 18
# ****Alignment****
# sequence: ref|XM_018493270.1| PREDICTED: Trachymyrmex septentrionalis U3 small nucleolar ribonucleoprotein protein MPP10 (LOC108752448), mRNA
# length: 1952
# e value: 41.8509
# TTTTTAACTATTTGATCT
# ||||||||||||||||||
# TTTTTAACTATTTGATCT
# 0
# 18
# ****Alignment****
# sequence: dbj|AP014963.1| Oryza sativa Japonica Group DNA, chromosome 7, cultivar: Nipponbare, complete sequence
# length: 29697621
# e value: 41.8509
# TTTTTAACTATTTGATCT
# ||||||||||||||||||
# TTTTTAACTATTTGATCT
# 0
# 18
# ****Alignment****
# sequence: dbj|AP014963.1| Oryza sativa Japonica Group DNA, chromosome 7, cultivar: Nipponbare, complete sequence
# length: 29697621
# e value: 41.8509
# TTTTTAACTATTTGATCT
# ||||||||||||||||||
# TTTTTAACTATTTGATCT
# 0
# 18
# ****Alignment****
# sequence: gb|CP012615.1| Oryza sativa Indica Group cultivar RP Bio-226 chromosome 7 sequence
# length: 26660614
# e value: 41.8509
# TTTTTAACTATTTGATCT
# ||||||||||||||||||
# TTTTTAACTATTTGATCT
# 0
# 18
# ****Alignment****
# sequence: ref|XM_013234231.1| PREDICTED: Biomphalaria glabrata ribonuclease H2 subunit C-like (LOC106073621), mRNA
# length: 1009
# e value: 41.8509
# TTTTTAACTATTTGATCT
# ||||||||||||||||||
# TTTTTAACTATTTGATCT
# 0
# 18
# ****Alignment****
# sequence: gb|CP011895.1| Ovis canadensis canadensis isolate 43U chromosome 10 sequence
# length: 86551329
# e value: 41.8509
# CTTTTTAACTATTTGATCTCT
# |||||||| ||||||||||||
# CTTTTTAAGTATTTGATCTCT
# 0
# 20
# ****Alignment****
# sequence: gb|CP011895.1| Ovis canadensis canadensis isolate 43U chromosome 10 sequence
# length: 86551329
# e value: 150.522
# TTTTAACTATTTGATCT
# |||||||||||||||||
# TTTTAACTATTTGATCT
# 0
# 17
# ****Alignment****
# sequence: gb|CP011895.1| Ovis canadensis canadensis isolate 43U chromosome 10 sequence
# length: 86551329
# e value: 150.522
# TTAACTATTTGATCTCT
# |||||||||||||||||
# TTAACTATTTGATCTCT
# 0
# 17
# ****Alignment****
# sequence: gb|CP011895.1| Ovis canadensis canadensis isolate 43U chromosome 10 sequence
# length: 86551329
# e value: 541.375
# TTTTTAACTATTTGAT
# ||||||||||||||||
# TTTTTAACTATTTGAT
# 0
# 16
# ****Alignment****
# sequence: gb|CP011895.1| Ovis canadensis canadensis isolate 43U chromosome 10 sequence
# length: 86551329
# e value: 541.375
# TTTTAACTATTTGATCTCT
# |||| ||||||||||||||
# TTTTCACTATTTGATCTCT
# 0
# 18
# ****Alignment****
# sequence: ref|XM_001018445.3| Tetrahymena thermophila SB210 cyclic nucleotide-binding domain protein partial mRNA
# length: 4047
# e value: 41.8509
# GCTTTTTAACTATTTGAT
# ||||||||||||||||||
# GCTTTTTAACTATTTGAT
# 0
# 18
# ****Alignment****
# sequence: emb|LN713259.1| Cucumis melo genomic chromosome, chr_5
# length: 28337775
# e value: 41.8509
# TTTTTAACTATTTGATCT
# ||||||||||||||||||
# TTTTTAACTATTTGATCT
# 0
# 18
# ****Alignment****
# sequence: emb|LN713259.1| Cucumis melo genomic chromosome, chr_5
# length: 28337775
# e value: 541.375
# TTTTTAACTATTTGAT
# ||||||||||||||||
# TTTTTAACTATTTGAT
# 0
# 16
# ****Alignment****
# sequence: emb|LN713259.1| Cucumis melo genomic chromosome, chr_5
# length: 28337775
# e value: 541.375
# TTTTTAACTATTTGATCTC
# |||||||||||||||| ||
# TTTTTAACTATTTGATGTC
# 0
# 18
# ****Alignment****
# sequence: emb|LN681847.1| Cucumis melo genomic scaffold, anchoredscaffold00003
# length: 9058246
# e value: 41.8509
# TTTTTAACTATTTGATCT
# ||||||||||||||||||
# TTTTTAACTATTTGATCT
# 0
# 18
# ****Alignment****
# sequence: emb|LM525806.1| Strongyloides papillosus genome assembly S_papillosus_LIN ,scaffold SPAL_scaffold0000062
# length: 49742
# e value: 41.8509
# TTTTAACTATTTGATCTC
# ||||||||||||||||||
# TTTTAACTATTTGATCTC
# 0
# 18
# ****Alignment****
# sequence: emb|LK489320.1| Dicrocoelium dendriticum genome assembly D_dendriticum_Leon_v1_0_4, scaffold DDEL_scaffold0091332
# length: 1439
# e value: 41.8509
# GCTTTTTAACTATTTGAT
# ||||||||||||||||||
# GCTTTTTAACTATTTGAT
# 0
# 18
# ****Alignment****
# sequence: emb|HG975442.1| Solanum pennellii chromosome ch03, complete genome
# length: 75414019
# e value: 41.8509
# CTTTTTAACTATTTGATC
# ||||||||||||||||||
# CTTTTTAACTATTTGATC
# 0
# 18
# ****Alignment****
# sequence: emb|HG975442.1| Solanum pennellii chromosome ch03, complete genome
# length: 75414019
# e value: 541.375
# GCTTTTTAACTATTTGATC
# ||||||| |||||||||||
# GCTTTTTTACTATTTGATC
# 0
# 18
# ****Alignment****
# sequence: emb|LR812510.1| Danio aesculapii genome assembly, chromosome: 9
# length: 58433418
# e value: 41.8509
# GCTTTTTAACTATTTGAT
# ||||||||||||||||||
# GCTTTTTAACTATTTGAT
# 0
# 18
# ****Alignment****
# sequence: emb|LR812510.1| Danio aesculapii genome assembly, chromosome: 9
# length: 58433418
# e value: 150.522
# GCTTTTTAACTATTTGATCT
# |||||||||||||||| |||
# GCTTTTTAACTATTTGTTCT
# 0
# 19
# ****Alignment****
# sequence: emb|LR812510.1| Danio aesculapii genome assembly, chromosome: 9
# length: 58433418
# e value: 150.522
# GCTTTTTAACTATTTGATCT
# |||||||||||||||| |||
# GCTTTTTAACTATTTGTTCT
# 0
# 19
# ****Alignment****
# sequence: emb|LR812510.1| Danio aesculapii genome assembly, chromosome: 9
# length: 58433418
# e value: 150.522
# GCTTTTTAACTATTTGATCT
# |||||||||||||||| |||
# GCTTTTTAACTATTTGTTCT
# 0
# 19
# ****Alignment****
# sequence: emb|LR812510.1| Danio aesculapii genome assembly, chromosome: 9
# length: 58433418
# e value: 150.522
# TTTTAACTATTTGATCT
# |||||||||||||||||
# TTTTAACTATTTGATCT
# 0
# 17
# ****Alignment****
# sequence: gb|CP002843.1| Streptococcus parasanguinis ATCC 15912, complete genome
# length: 2153652
# e value: 41.8509
# TTTTTAACTATTTGATCT
# ||||||||||||||||||
# TTTTTAACTATTTGATCT
# 0
# 18
# ****Alignment****
# sequence: emb|CU405721.12| Pig DNA sequence from clone CH242-386C18 on chromosome X, complete sequence
# length: 166387
# e value: 41.8509
# CTTTTTAACTATTTGATCTCT
# |||| ||||||||||||||||
# CTTTATAACTATTTGATCTCT
# 0
# 20
# ****Alignment****
# sequence: gb|HM561625.1| Histiotus magellanicus voucher OMNH23500 (OCGR2303) tRNA-Phe gene, partial sequence; 12S ribosomal RNA and tRNA-Val genes, complete sequence; and 16S ribosomal RNA gene, partial sequence; mitochondrial
# length: 2657
# e value: 41.8509
# CTTT-TTAACTATTTGATCTCT
# |||| |||||||||||||||||
# CTTTATTAACTATTTGATCTCT
# 1
# 21
# ****Alignment****
# sequence: ref|XM_002257714.1| Plasmodium knowlesi strain H SICA antigen (fragment) partial mRNA
# length: 3177
# e value: 41.8509
# CTTTTTAACTATTTGATC
# ||||||||||||||||||
# CTTTTTAACTATTTGATC
# 0
# 18
# ****Alignment****
# sequence: gb|AC195453.1| Medicago truncatula clone mth2-43p1, complete sequence
# length: 124269
# e value: 41.8509
# TTTTTAACTATTTGATCT
# ||||||||||||||||||
# TTTTTAACTATTTGATCT
# 0
# 18
# ****Alignment****
# sequence: ref|XM_001861726.1| Culex quinquefasciatus conserved hypothetical protein, mRNA
# length: 1071
# e value: 41.8509
# TTTTAACTATTTGATCTC
# ||||||||||||||||||
# TTTTAACTATTTGATCTC
# 0
# 18
# ****Alignment****
# sequence: ref|XM_001845134.1| Culex quinquefasciatus conserved hypothetical protein, mRNA
# length: 1953
# e value: 41.8509
# TTTTAACTATTTGATCTC
# ||||||||||||||||||
# TTTTAACTATTTGATCTC
# 0
# 18
# ****Alignment****
# sequence: gb|AC148969.5| Medicago truncatula chromosome 2 BAC clone mth2-58p1, complete sequence
# length: 73553
# e value: 41.8509
# TTTTTAACTATTTGATCT
# ||||||||||||||||||
# TTTTTAACTATTTGATCT
# 0
# 18
# ****Alignment****
# sequence: gb|AC161519.11| Mus musculus chromosome 18, clone RP24-83L9, complete sequence
# length: 233631
# e value: 41.8509
# TTTAACTATTTGATCTCT
# ||||||||||||||||||
# TTTAACTATTTGATCTCT
# 0
# 18
# ****Alignment****
# sequence: gb|AC148340.3| Medicago truncatula chromosome 2 clone mth2-22d10, complete sequence
# length: 105618
# e value: 41.8509
# TTTTTAACTATTTGATCT
# ||||||||||||||||||
# TTTTTAACTATTTGATCT
# 0
# 18
# ****Alignment****
# sequence: gb|AC089987.26| Homo sapiens 12q BAC RP11-722P11 (Roswell Park Cancer Institute Human BAC Library) complete sequence
# length: 164945
# e value: 41.8509
# CTTTTTAACTATTTGATC
# ||||||||||||||||||
# CTTTTTAACTATTTGATC
# 0
# 18
# ****Alignment****
# sequence: dbj|AP003754.5| Oryza sativa Japonica Group genomic DNA, chromosome 7, BAC clone:OJ1341_A08
# length: 128955
# e value: 41.8509
# TTTTTAACTATTTGATCT
# ||||||||||||||||||
# TTTTTAACTATTTGATCT
# 0
# 18
# ****Alignment****
# sequence: dbj|AP005178.3| Oryza sativa Japonica Group genomic DNA, chromosome 7, BAC clone:OSJNBb0056I06
# length: 138653
# e value: 41.8509
# TTTTTAACTATTTGATCT
# ||||||||||||||||||
# TTTTTAACTATTTGATCT
# 0
# 18
# ****Alignment****
# sequence: gb|AC105921.5| Homo sapiens BAC clone RP11-541F21 from 2, complete sequence
# length: 188183
# e value: 41.8509
# CTTTTTAACTATTTGATCTCT
# |||||||||||||| ||||||
# CTTTTTAACTATTTTATCTCT
# 0
# 20
# ****Alignment****
# sequence: dbj|AP004382.2| Oryza sativa Japonica Group genomic DNA, chromosome 7, PAC clone:P0418E08
# length: 141040
# e value: 41.8509
# TTTTTAACTATTTGATCT
# ||||||||||||||||||
# TTTTTAACTATTTGATCT
# 0
# 18
# ****Alignment****
# sequence: gb|AC113618.5| Homo sapiens BAC clone RP11-1367O10 from 2, complete sequence
# length: 199917
# e value: 41.8509
# GCTTTTTAACTATTTGAT
# ||||||||||||||||||
# GCTTTTTAACTATTTGAT
# 0
# 18
# ****Alignment****
# sequence: gb|AC092619.3| Homo sapiens BAC clone RP11-225M4 from 2, complete sequence
# length: 163475
# e value: 41.8509
# GCTTTTTAACTATTTGAT
# ||||||||||||||||||
# GCTTTTTAACTATTTGAT
# 0
# 18
# ****Alignment****
# sequence: gb|AC068970.6| Homo sapiens BAC clone RP11-84F8 from 2, complete sequence
# length: 185993
# e value: 41.8509
# CTTTTTAACTATTTGATCTCT
# |||||||||||||| ||||||
# CTTTTTAACTATTTTATCTCT
# 0
# 20
# ****Alignment****
# sequence: gb|AC062032.5| Homo sapiens BAC clone RP11-515K12 from 2, complete sequence
# length: 182147
# e value: 41.8509
# TTTTTAACTATTTGATCT
# ||||||||||||||||||
# TTTTTAACTATTTGATCT
# 0
# 18
# ****Alignment****
# sequence: emb|LR812508.1| Danio aesculapii genome assembly, chromosome: 10
# length: 46123639
# e value: 150.522
# TTTTAACTATTTGATCT
# |||||||||||||||||
# TTTTAACTATTTGATCT
# 0
# 17
# ****Alignment****
# sequence: emb|LR812506.1| Danio aesculapii genome assembly, chromosome: 11
# length: 47054533
# e value: 150.522
# TTTTAACTATTTGATCT
# |||||||||||||||||
# TTTTAACTATTTGATCT
# 0
# 17
# ****Alignment****
# sequence: emb|LR812109.1| Erithacus rubecula genome assembly, chromosome: 7
# length: 46560559
# e value: 150.522
# CTTTTTAACTATTTGATCTC
# |||||||| |||||||||||
# CTTTTTAATTATTTGATCTC
# 0
# 19
# ****Alignment****
# sequence: emb|LR812109.1| Erithacus rubecula genome assembly, chromosome: 7
# length: 46560559
# e value: 150.522
# TTT-TTAACTATTTGATCTCT
# ||| |||||||||||||||||
# TTTATTAACTATTTGATCTCT
# 1
# 20
# ****Alignment****
# sequence: emb|LR812086.1| Danio rerio genome assembly, chromosome: 24
# length: 42362946
# e value: 150.522
# CTTTTTAACTATTTGAT
# |||||||||||||||||
# CTTTTTAACTATTTGAT
# 0
# 17
# ****Alignment****
# sequence: emb|LR812086.1| Danio rerio genome assembly, chromosome: 24
# length: 42362946
# e value: 541.375
# CTTTTTAACTATTTGATCT
# || ||||||||||||||||
# CTATTTAACTATTTGATCT
# 0
# 18
# ****Alignment****
# sequence: emb|LR812071.1| Danio rerio genome assembly, chromosome: 9
# length: 56856035
# e value: 150.522
# GCTTTTTAACTATTTGATCT
# |||||||||||||||| |||
# GCTTTTTAACTATTTGTTCT
# 0
# 19
# ****Alignment****
# sequence: emb|LR812071.1| Danio rerio genome assembly, chromosome: 9
# length: 56856035
# e value: 541.375
# GCTTTTTAACTATTTGATC
# ||||| |||||||||||||
# GCTTTATAACTATTTGATC
# 0
# 18
# ****Alignment****
# sequence: emb|LR812067.1| Danio rerio genome assembly, chromosome: 5
# length: 72587816
# e value: 150.522
# TTTTAACTATTTGATCT
# |||||||||||||||||
# TTTTAACTATTTGATCT
# 0
# 17
# ****Alignment****
# sequence: gb|CP053837.1| Aliiarcobacter faecis strain CCUG 66484 chromosome, complete genome
# length: 2308709
# e value: 150.522
# GCTTTTTAACTATTTGA
# |||||||||||||||||
# GCTTTTTAACTATTTGA
# 0
# 17
# ****Alignment****
# sequence: ref|XM_034630037.1| PREDICTED: Drosophila innubila cardio acceleratory peptide 2b (LOC117790556), mRNA
# length: 812
# e value: 150.522
# TTTTTAACTATTTGATCTCT
# ||||||| ||||||||||||
# TTTTTAATTATTTGATCTCT
# 0
# 19
# ****Alignment****
# sequence: ref|XM_034516862.1| PREDICTED: Arvicanthis niloticus limb development membrane protein 1 like (Lmbr1l), transcript variant X1, mRNA
# length: 2983
# e value: 150.522
# TTTTTAACTATTTGATCTCT
# |||||||||||||| |||||
# TTTTTAACTATTTGTTCTCT
# 0
# 19
# ****Alignment****
# sequence: ref|XM_034350861.1| PREDICTED: Prunus dulcis membrane-anchored ubiquitin-fold protein 2-like (LOC117620703), transcript variant X3, mRNA
# length: 1044
# e value: 150.522
# CTTTTTAACTATTTGATCTCT
# |||||| ||||||||||||||
# CTTTTT-ACTATTTGATCTCT
# 1
# 20
# ****Alignment****
# sequence: ref|XM_034350860.1| PREDICTED: Prunus dulcis membrane-anchored ubiquitin-fold protein 2-like (LOC117620703), transcript variant X2, mRNA
# length: 1117
# e value: 150.522
# CTTTTTAACTATTTGATCTCT
# |||||| ||||||||||||||
# CTTTTT-ACTATTTGATCTCT
# 1
# 20
# ****Alignment****
# sequence: gb|CP051206.1| Dolichospermum flos-aquae CCAP 1403/13F chromosome, complete genome
# length: 5151752
# e value: 150.522
# TTTTTAACTATTTGATCTCT
# |||||||||||||| |||||
# TTTTTAACTATTTGCTCTCT
# 0
# 19
# ****Alignment****
# sequence: emb|LR792565.1| Pseudochaenichthys georgianus genome assembly, chromosome: 20
# length: 24389971
# e value: 150.522
# TTTTAACTATTTGATCT
# |||||||||||||||||
# TTTTAACTATTTGATCT
# 0
# 17
# ****Alignment****
# sequence: emb|LR792551.1| Pseudochaenichthys georgianus genome assembly, chromosome: 6
# length: 45575153
# e value: 150.522
# TTTTAACTATTTGATCT
# |||||||||||||||||
# TTTTAACTATTTGATCT
# 0
# 17
# ****Alignment****
# sequence: gb|CP050228.1| Morus alba cultivar Heyebai chromosome 5
# length: 23460841
# e value: 150.522
# CTTTTTAACTATTTGATCTC
# ||||||||||| ||||||||
# CTTTTTAACTAATTGATCTC
# 0
# 19
# ****Alignment****
# sequence: gb|CP050225.1| Morus alba cultivar Heyebai chromosome 2
# length: 35990041
# e value: 150.522
# TTTTAACTATTTGATCT
# |||||||||||||||||
# TTTTAACTATTTGATCT
# 0
# 17
# ****Alignment****
# sequence: gb|CP050225.1| Morus alba cultivar Heyebai chromosome 2
# length: 35990041
# e value: 541.375
# TTTTAACTATTTGATC
# ||||||||||||||||
# TTTTAACTATTTGATC
# 0
# 16
# ****Alignment****
# sequence: gb|CP050225.1| Morus alba cultivar Heyebai chromosome 2
# length: 35990041
# e value: 541.375
# CTTTTTAACTATTTGATCT
# |||||||||| ||||||||
# CTTTTTAACTGTTTGATCT
# 0
# 18
# ****Alignment****
# sequence: gb|CP050605.1| Canis lupus familiaris breed Labrador retriever chromosome 34a
# length: 45451182
# e value: 150.522
# TTTTTAACTATTTGATCTCT
# ||||| ||||||||||||||
# TTTTTTACTATTTGATCTCT
# 0
# 19
# ****Alignment****
# sequence: gb|CP050594.1| Canis lupus familiaris breed Labrador retriever chromosome 33a
# length: 31580840
# e value: 150.522
# TTTTTAACTATTTGATCTCT
# |||||||||| |||||||||
# TTTTTAACTACTTGATCTCT
# 0
# 19
# ****Alignment****
# sequence: gb|CP050578.1| Canis lupus familiaris breed Labrador retriever chromosome 12a
# length: 72572423
# e value: 150.522
# TTTTT-AACTATTTGATCTCT
# ||||| |||||||||||||||
# TTTTTAAACTATTTGATCTCT
# 1
# 20
# ****Alignment****
# sequence: gb|CP050578.1| Canis lupus familiaris breed Labrador retriever chromosome 12a
# length: 72572423
# e value: 541.375
# CTTTTTAACTATTTGA
# ||||||||||||||||
# CTTTTTAACTATTTGA
# 0
# 16
# ****Alignment****
# sequence: gb|CP050578.1| Canis lupus familiaris breed Labrador retriever chromosome 12a
# length: 72572423
# e value: 541.375
# CTTTTTAACTATTTGA
# ||||||||||||||||
# CTTTTTAACTATTTGA
# 0
# 16
# ****Alignment****
# sequence: gb|CP050578.1| Canis lupus familiaris breed Labrador retriever chromosome 12a
# length: 72572423
# e value: 541.375
# TTTTAACTATTTGATCTCT
# ||||||| |||||||||||
# TTTTAACCATTTGATCTCT
# 0
# 18
# ****Alignment****
# sequence: gb|CP050572.1| Canis lupus familiaris breed Labrador retriever chromosome 04a
# length: 86937822
# e value: 150.522
# TTTTTAACTATTTGATCTCT
# |||||||||||||||| |||
# TTTTTAACTATTTGATGTCT
# 0
# 19
# ****Alignment****
# sequence: gb|CP050572.1| Canis lupus familiaris breed Labrador retriever chromosome 04a
# length: 86937822
# e value: 541.375
# TTTTTAACTATTTGAT
# ||||||||||||||||
# TTTTTAACTATTTGAT
# 0
# 16
# ****Alignment****
# sequence: gb|CP050625.1| Canis lupus familiaris breed Labrador retriever chromosome 04b
# length: 86945037
# e value: 150.522
# TTTTTAACTATTTGATCTCT
# |||||||||||||||| |||
# TTTTTAACTATTTGATGTCT
# 0
# 19
# ****Alignment****
# sequence: gb|CP050625.1| Canis lupus familiaris breed Labrador retriever chromosome 04b
# length: 86945037
# ...
# ||| ||||||||||||||||
# CACGGTTGAGACAGCGTCCA
# 1
# 19
# ****Alignment****
# sequence: emb|LR699004.1| Bacteroides dorei isolate MGYG-HGUT-02478 genome assembly, chromosome: 1 >gb|CP009057.1| Bacteroides dorei isolate HS2_L_2_B_045b, complete genome
# length: 5444912
# e value: 541.375
# CAC-GTTGAGACAGCGTCCA
# ||| ||||||||||||||||
# CACGGTTGAGACAGCGTCCA
# 1
# 19
# ****Alignment****
# sequence: emb|LR699004.1| Bacteroides dorei isolate MGYG-HGUT-02478 genome assembly, chromosome: 1 >gb|CP009057.1| Bacteroides dorei isolate HS2_L_2_B_045b, complete genome
# length: 5444912
# e value: 541.375
# CAC-GTTGAGACAGCGTCCAAAT
# ||| |||||||||||||||| ||
# CACGGTTGAGACAGCGTCCAGAT
# 1
# 21
# ****Alignment****
# sequence: emb|LR699004.1| Bacteroides dorei isolate MGYG-HGUT-02478 genome assembly, chromosome: 1 >gb|CP009057.1| Bacteroides dorei isolate HS2_L_2_B_045b, complete genome
# length: 5444912
# e value: 541.375
# CAC-GTTGAGACAGCGTCCAAAT
# ||| |||||||||||||||| ||
# CACGGTTGAGACAGCGTCCAGAT
# 1
# 21
# ****Alignment****
# sequence: emb|LR699004.1| Bacteroides dorei isolate MGYG-HGUT-02478 genome assembly, chromosome: 1 >gb|CP009057.1| Bacteroides dorei isolate HS2_L_2_B_045b, complete genome
# length: 5444912
# e value: 541.375
# CAC-GTTGAGACAGCGTCCA
# ||| ||||||||||||||||
# CACGGTTGAGACAGCGTCCA
# 1
# 19
# ****Alignment****
# sequence: emb|LR699004.1| Bacteroides dorei isolate MGYG-HGUT-02478 genome assembly, chromosome: 1 >gb|CP009057.1| Bacteroides dorei isolate HS2_L_2_B_045b, complete genome
# length: 5444912
# e value: 541.375
# CAC-GTTGAGACAGCGTCCA
# ||| ||||||||||||||||
# CACGGTTGAGACAGCGTCCA
# 1
# 19
# ****Alignment****
# sequence: ref|XM_012894241.1| Acytostelium subglobosum LB1 hypothetical protein partial mRNA
# length: 4419
# e value: 541.375
# TTGAGACAGCGTCCAA
# ||||||||||||||||
# TTGAGACAGCGTCCAA
# 0
# 16
# ****Alignment****
# sequence: ref|NM_001030989.2| Gallus gallus SH3 domain binding protein 5 (SH3BP5), mRNA
# length: 2612
# e value: 541.375
# TTGAGACAGCGTCCAA
# ||||||||||||||||
# TTGAGACAGCGTCCAA
# 0
# 16
# ****Alignment****
# sequence: ref|XM_011050974.1| PREDICTED: Acromyrmex echinatior putative ferric-chelate reductase 1 homolog (LOC105143006), mRNA
# length: 2668
# e value: 541.375
# CACGTTGAGACAGCGTCCA
# ||||||||||| |||||||
# CACGTTGAGACGGCGTCCA
# 0
# 18
# ****Alignment****
# sequence: gb|CP008741.1| Bacteroides dorei isolate HS1_L_3_B_079, complete genome
# length: 5243219
# e value: 541.375
# CAC-GTTGAGACAGCGTCCA
# ||| ||||||||||||||||
# CACGGTTGAGACAGCGTCCA
# 1
# 19
# ****Alignment****
# sequence: gb|CP008741.1| Bacteroides dorei isolate HS1_L_3_B_079, complete genome
# length: 5243219
# e value: 541.375
# CAC-GTTGAGACAGCGTCCA
# ||| ||||||||||||||||
# CACGGTTGAGACAGCGTCCA
# 1
# 19
# ****Alignment****
# sequence: gb|CP008741.1| Bacteroides dorei isolate HS1_L_3_B_079, complete genome
# length: 5243219
# e value: 541.375
# CAC-GTTGAGACAGCGTCCAAAT
# ||| |||||||||||||||| ||
# CACGGTTGAGACAGCGTCCAGAT
# 1
# 21
# ****Alignment****
# sequence: gb|CP008741.1| Bacteroides dorei isolate HS1_L_3_B_079, complete genome
# length: 5243219
# e value: 541.375
# CAC-GTTGAGACAGCGTCCAAAT
# ||| |||||||||||||||| ||
# CACGGTTGAGACAGCGTCCAGAT
# 1
# 21
# ****Alignment****
# sequence: gb|CP008741.1| Bacteroides dorei isolate HS1_L_3_B_079, complete genome
# length: 5243219
# e value: 541.375
# CAC-GTTGAGACAGCGTCCAAAT
# ||| |||||||||||||||| ||
# CACGGTTGAGACAGCGTCCAGAT
# 1
# 21
# ****Alignment****
# sequence: gb|CP008741.1| Bacteroides dorei isolate HS1_L_3_B_079, complete genome
# length: 5243219
# e value: 541.375
# CAC-GTTGAGACAGCGTCCA
# ||| ||||||||||||||||
# CACGGTTGAGACAGCGTCCA
# 1
# 19
# ****Alignment****
# sequence: gb|CP007619.1| Bacteroides dorei isolate HS1_L_1_B_010, complete genome
# length: 5729085
# e value: 541.375
# CAC-GTTGAGACAGCGTCCAAAT
# ||| |||||||||||||||| ||
# CACGGTTGAGACAGCGTCCAGAT
# 1
# 21
# ****Alignment****
# sequence: gb|CP007619.1| Bacteroides dorei isolate HS1_L_1_B_010, complete genome
# length: 5729085
# e value: 541.375
# CAC-GTTGAGACAGCGTCCA
# ||| ||||||||||||||||
# CACGGTTGAGACAGCGTCCA
# 1
# 19
# ****Alignment****
# sequence: gb|CP007619.1| Bacteroides dorei isolate HS1_L_1_B_010, complete genome
# length: 5729085
# e value: 541.375
# CAC-GTTGAGACAGCGTCCA
# ||| ||||||||||||||||
# CACGGTTGAGACAGCGTCCA
# 1
# 19
# ****Alignment****
# sequence: gb|CP007619.1| Bacteroides dorei isolate HS1_L_1_B_010, complete genome
# length: 5729085
# e value: 541.375
# CAC-GTTGAGACAGCGTCCA
# ||| ||||||||||||||||
# CACGGTTGAGACAGCGTCCA
# 1
# 19
# ****Alignment****
# sequence: gb|CP007619.1| Bacteroides dorei isolate HS1_L_1_B_010, complete genome
# length: 5729085
# e value: 541.375
# CAC-GTTGAGACAGCGTCCA
# ||| ||||||||||||||||
# CACGGTTGAGACAGCGTCCA
# 1
# 19
# ****Alignment****
# sequence: gb|CP007619.1| Bacteroides dorei isolate HS1_L_1_B_010, complete genome
# length: 5729085
# e value: 541.375
# CAC-GTTGAGACAGCGTCCA
# ||| ||||||||||||||||
# CACGGTTGAGACAGCGTCCA
# 1
# 19
# ****Alignment****
# sequence: gb|CP007619.1| Bacteroides dorei isolate HS1_L_1_B_010, complete genome
# length: 5729085
# e value: 541.375
# CAC-GTTGAGACAGCGTCCA
# ||| ||||||||||||||||
# CACGGTTGAGACAGCGTCCA
# 1
# 19
# ****Alignment****
# sequence: ref|XM_008024142.1| Exserohilum turcica Et28A uncharacterized protein (SETTUDRAFT_167337), mRNA
# length: 1003
# e value: 541.375
# GTTGAGACAGCGTCCAAAT
# ||||||| |||||||||||
# GTTGAGAAAGCGTCCAAAT
# 0
# 18
# ****Alignment****
# sequence: ref|NR_103124.1| Prevotella melaninogenica strain Finegold B282 23S ribosomal RNA gene, complete sequence
# length: 2838
# e value: 541.375
# GTTGAGACAGCGTCCAAAT
# |||||||||||||||| ||
# GTTGAGACAGCGTCCAGAT
# 0
# 18
# ****Alignment****
# sequence: ref|NR_076809.1| Bacteroides helcogenes strain P 36-108 23S ribosomal RNA gene, complete sequence
# length: 2878
# e value: 541.375
# CAC-GTTGAGACAGCGTCCAAAT
# ||| |||||||||||||||| ||
# CACGGTTGAGACAGCGTCCAGAT
# 1
# 21
# ****Alignment****
# sequence: ref|NR_076734.1| Denitrovibrio acetiphilus strain N2460 23S ribosomal RNA gene, complete sequence
# length: 2920
# e value: 541.375
# GTTGAGACAGCGTCCAAAT
# |||||||||||||||| ||
# GTTGAGACAGCGTCCAGAT
# 0
# 18
# ****Alignment****
# sequence: ref|NR_076384.1| Bacteroides vulgatus strain ATCC 8482 23S ribosomal RNA gene, complete sequence
# length: 2894
# e value: 541.375
# CAC-GTTGAGACAGCGTCCAAAT
# ||| |||||||||||||||| ||
# CACGGTTGAGACAGCGTCCAGAT
# 1
# 21
# ****Alignment****
# sequence: gb|AC246525.4| Rattus norvegicus Y Chr BAC RNECO-131C03 (Amplicon Express Rat SHR-Akr (EcoR1 Digest) BAC library) complete sequence
# length: 171320
# e value: 541.375
# GTTGAGACAGCGTCCAAAT
# ||||||||||| |||||||
# GTTGAGACAGCATCCAAAT
# 0
# 18
# ****Alignment****
# sequence: gb|CP003620.1| Crinalium epipsammum PCC 9333, complete genome
# length: 5315554
# e value: 541.375
# GTTGAGACAGCGTCCAAAT
# ||||||||||||| |||||
# GTTGAGACAGCGTTCAAAT
# 0
# 18
# ****Alignment****
# sequence: gb|CP059162.1| Pseudomonas chlororaphis subsp. aurantiaca strain YS05 chromosome, complete genome
# length: 6953033
# e value: 541.375
# GTTGAGACAGCGTCCA
# ||||||||||||||||
# GTTGAGACAGCGTCCA
# 0
# 16
# ****Alignment****
# sequence: gb|CP054634.1| Exserohilum turcica Et28A chromosome 8
# length: 2274269
# e value: 541.375
# GTTGAGACAGCGTCCAAAT
# ||||||| |||||||||||
# GTTGAGAAAGCGTCCAAAT
# 0
# 18
# ****Alignment****
# sequence: gb|AC243737.5| Rattus norvegicus Y Chr BAC RNECO-236E21 (Amplicon Express Rat SHR-Akr (EcoR1 Digest) BAC library) complete sequence
# length: 135071
# e value: 541.375
# GTTGAGACAGCGTCCAAAT
# ||||||||||| |||||||
# GTTGAGACAGCATCCAAAT
# 0
# 18
# ****Alignment****
# sequence: gb|CP002352.1| Bacteroides helcogenes P 36-108, complete genome
# length: 3998906
# e value: 541.375
# CAC-GTTGAGACAGCGTCCA
# ||| ||||||||||||||||
# CACGGTTGAGACAGCGTCCA
# 1
# 19
# ****Alignment****
# sequence: gb|CP002352.1| Bacteroides helcogenes P 36-108, complete genome
# length: 3998906
# e value: 541.375
# CAC-GTTGAGACAGCGTCCA
# ||| ||||||||||||||||
# CACGGTTGAGACAGCGTCCA
# 1
# 19
# ****Alignment****
# sequence: gb|CP002352.1| Bacteroides helcogenes P 36-108, complete genome
# length: 3998906
# e value: 541.375
# CAC-GTTGAGACAGCGTCCAAAT
# ||| |||||||||||||||| ||
# CACGGTTGAGACAGCGTCCAGAT
# 1
# 21
# ****Alignment****
# sequence: gb|CP002352.1| Bacteroides helcogenes P 36-108, complete genome
# length: 3998906
# e value: 541.375
# CAC-GTTGAGACAGCGTCCAAAT
# ||| |||||||||||||||| ||
# CACGGTTGAGACAGCGTCCAGAT
# 1
# 21
# ****Alignment****
# sequence: gb|CP002352.1| Bacteroides helcogenes P 36-108, complete genome
# length: 3998906
# e value: 541.375
# CAC-GTTGAGACAGCGTCCA
# ||| ||||||||||||||||
# CACGGTTGAGACAGCGTCCA
# 1
# 19
# ****Alignment****
# sequence: gb|CP002123.1| Prevotella melaninogenica ATCC 25845 chromosome II, complete sequence
# length: 1371874
# e value: 541.375
# GTTGAGACAGCGTCCA
# ||||||||||||||||
# GTTGAGACAGCGTCCA
# 0
# 16
# ****Alignment****
# sequence: gb|CP002122.1| Prevotella melaninogenica ATCC 25845 chromosome I, complete sequence
# length: 1796408
# e value: 541.375
# GTTGAGACAGCGTCCAAAT
# |||||||||||||||| ||
# GTTGAGACAGCGTCCAGAT
# 0
# 18
# ****Alignment****
# sequence: gb|CP002122.1| Prevotella melaninogenica ATCC 25845 chromosome I, complete sequence
# length: 1796408
# e value: 541.375
# GTTGAGACAGCGTCCA
# ||||||||||||||||
# GTTGAGACAGCGTCCA
# 0
# 16
# ****Alignment****
# sequence: gb|CP002122.1| Prevotella melaninogenica ATCC 25845 chromosome I, complete sequence
# length: 1796408
# e value: 541.375
# GTTGAGACAGCGTCCA
# ||||||||||||||||
# GTTGAGACAGCGTCCA
# 0
# 16
# ****Alignment****
# sequence: gb|HM007615.1| Atopobium minutum strain 23 23S ribosomal RNA gene, partial sequence
# length: 1525
# e value: 541.375
# GTTGAGACAGCGTCCAAAT
# |||||||||| ||||||||
# GTTGAGACAGTGTCCAAAT
# 0
# 18
# ****Alignment****
# sequence: gb|HM007614.1| Atopobium minutum strain DSM 20586 23S ribosomal RNA gene, partial sequence
# length: 1529
# e value: 541.375
# GTTGAGACAGCGTCCAAAT
# |||||||||| ||||||||
# GTTGAGACAGTGTCCAAAT
# 0
# 18
# ****Alignment****
# sequence: gb|HM007594.1| Atopobium vaginae DSM 15829 23S ribosomal RNA gene, partial sequence
# length: 2565
# e value: 541.375
# GTTGAGACAGCGTCCAAAT
# |||||||||| ||||||||
# GTTGAGACAGTGTCCAAAT
# 0
# 18
# ****Alignment****
# sequence: gb|GU924434.1| Uncultured bacterium clone F5K2Q4C04I2BDJ 23S ribosomal RNA gene, partial sequence
# length: 533
# e value: 541.375
# GTTGAGACAGCGTCCAAAT
# |||||||||||||||| ||
# GTTGAGACAGCGTCCAGAT
# 0
# 18
# ****Alignment****
# sequence: gb|CP001968.1| Denitrovibrio acetiphilus DSM 12809 chromosome, complete genome
# length: 3222077
# e value: 541.375
# GTTGAGACAGCGTCCA
# ||||||||||||||||
# GTTGAGACAGCGTCCA
# 0
# 16
# ****Alignment****
# sequence: gb|CP001968.1| Denitrovibrio acetiphilus DSM 12809 chromosome, complete genome
# length: 3222077
# e value: 541.375
# GTTGAGACAGCGTCCA
# ||||||||||||||||
# GTTGAGACAGCGTCCA
# 0
# 16
# ****Alignment****
# sequence: gb|GQ874294.1| Uncultured organism clone 1041059766462 genomic sequence
# length: 5385
# e value: 541.375
# CAC-GTTGAGACAGCGTCCA
# ||| ||||||||||||||||
# CACGGTTGAGACAGCGTCCA
# 1
# 19
# ****Alignment****
# sequence: gb|GQ873995.1| Uncultured organism clone 1041059765996 genomic sequence
# length: 1786
# e value: 541.375
# CAC-GTTGAGACAGCGTCCAAAT
# ||| |||||||||||||||| ||
# CACGGTTGAGACAGCGTCCAGAT
# 1
# 21
# ****Alignment****
# sequence: gb|GQ873849.1| Uncultured organism clone 1041059765761 genomic sequence
# length: 1692
# e value: 541.375
# CAC-GTTGAGACAGCGTCCAAAT
# ||| |||||||||||||||| ||
# CACGGTTGAGACAGCGTCCAGAT
# 1
# 21
# ****Alignment****
# sequence: gb|GQ873634.1| Uncultured organism clone 1041059765401 genomic sequence
# length: 3310
# e value: 541.375
# CAC-GTTGAGACAGCGTCCA
# ||| ||||||||||||||||
# CACGGTTGAGACAGCGTCCA
# 1
# 19
# ****Alignment****
# sequence: gb|GQ882485.1| Uncultured organism clone VC1D232TF genomic sequence
# length: 453
# e value: 541.375
# CAC-GTTGAGACAGCGTCCAAAT
# ||| |||||||||||||||| ||
# CACGGTTGAGACAGCGTCCAGAT
# 1
# 21
# ****Alignment****
# sequence: gb|GQ881882.1| Uncultured organism clone VC1CW05TF genomic sequence
# length: 952
# e value: 541.375
# CAC-GTTGAGACAGCGTCCA
# ||| ||||||||||||||||
# CACGGTTGAGACAGCGTCCA
# 1
# 19
# ****Alignment****
# sequence: gb|FJ410382.1| Bacteroides vulgatus KCCM:11423 16S ribosomal RNA gene, partial sequence; 16S-23S ribosomal intergenic spacer, complete sequence; and 23S ribosomal RNA gene, partial sequence
# length: 3340
# e value: 541.375
# CAC-GTTGAGACAGCGTCCAAAT
# ||| |||||||||||||||| ||
# CACGGTTGAGACAGCGTCCAGAT
# 1
# 21
# ****Alignment****
# sequence: ref|XM_001750313.1| Monosiga brevicollis MX1 uncharacterized protein (MONBRDRAFT_34526), partial mRNA
# length: 3900
# e value: 541.375
# ACGTTGAGACAGCGTCCAA
# |||||||||||||| ||||
# ACGTTGAGACAGCGGCCAA
# 0
# 18
# ****Alignment****
# sequence: emb|AM912888.1| Uncultured bacterium partial integron, gene cassette region, clone HHSO_9_49_1_1
# length: 338
# e value: 541.375
# CACGTTGAGACAGCGTCCA
# |||||||||| ||||||||
# CACGTTGAGATAGCGTCCA
# 0
# 18
# ****Alignment****
# sequence: gb|EU061490.1| Uncultured bacterium clone LM0ABA6ZG02RM1 genomic sequence
# length: 793
# e value: 541.375
# CAC-GTTGAGACAGCGTCCAAAT
# ||| |||||||||||||||| ||
# CACGGTTGAGACAGCGTCCAGAT
# 1
# 21
# ****Alignment****
# sequence: gb|EU061248.1| Uncultured bacterium clone LM0ABA42ZH03RM1 genomic sequence
# length: 268
# e value: 541.375
# CAC-GTTGAGACAGCGTCCA
# ||| ||||||||||||||||
# CACGGTTGAGACAGCGTCCA
# 1
# 19
# ****Alignment****
# sequence: gb|EU061157.1| Uncultured bacterium clone LM0ABA40ZH07RM1 genomic sequence
# length: 684
# e value: 541.375
# CAC-GTTGAGACAGCGTCCA
# ||| ||||||||||||||||
# CACGGTTGAGACAGCGTCCA
# 1
# 19
# ****Alignment****
# sequence: gb|EU060162.1| Uncultured bacterium clone LM0ABA2ZA06RM1 genomic sequence
# length: 786
# e value: 541.375
# CAC-GTTGAGACAGCGTCCAAAT
# ||| |||||||||||||||| ||
# CACGGTTGAGACAGCGTCCAGAT
# 1
# 21
# ****Alignment****
# sequence: gb|EU059365.1| Uncultured bacterium clone LM0ABA5ZF07FM1 genomic sequence
# length: 744
# e value: 541.375
# CAC-GTTGAGACAGCGTCCA
# ||| ||||||||||||||||
# CACGGTTGAGACAGCGTCCA
# 1
# 19
# ****Alignment****
# sequence: gb|EU058979.1| Uncultured bacterium clone LM0ABA4ZB12FM1 genomic sequence
# length: 689
# e value: 541.375
# CAC-GTTGAGACAGCGTCCA
# ||| ||||||||||||||||
# CACGGTTGAGACAGCGTCCA
# 1
# 19
# ****Alignment****
# sequence: gb|CP000139.1| Bacteroides vulgatus ATCC 8482, complete genome
# length: 5163189
# e value: 541.375
# CAC-GTTGAGACAGCGTCCA
# ||| ||||||||||||||||
# CACGGTTGAGACAGCGTCCA
# 1
# 19
# ****Alignment****
# sequence: gb|CP000139.1| Bacteroides vulgatus ATCC 8482, complete genome
# length: 5163189
# e value: 541.375
# CAC-GTTGAGACAGCGTCCA
# ||| ||||||||||||||||
# CACGGTTGAGACAGCGTCCA
# 1
# 19
# ****Alignment****
# sequence: gb|CP000139.1| Bacteroides vulgatus ATCC 8482, complete genome
# length: 5163189
# e value: 541.375
# CAC-GTTGAGACAGCGTCCAAAT
# ||| |||||||||||||||| ||
# CACGGTTGAGACAGCGTCCAGAT
# 1
# 21
# ****Alignment****
# sequence: gb|CP000139.1| Bacteroides vulgatus ATCC 8482, complete genome
# length: 5163189
# e value: 541.375
# CAC-GTTGAGACAGCGTCCAAAT
# ||| |||||||||||||||| ||
# CACGGTTGAGACAGCGTCCAGAT
# 1
# 21
# ****Alignment****
# sequence: gb|CP000139.1| Bacteroides vulgatus ATCC 8482, complete genome
# length: 5163189
# e value: 541.375
# CAC-GTTGAGACAGCGTCCAAAT
# ||| |||||||||||||||| ||
# CACGGTTGAGACAGCGTCCAGAT
# 1
# 21
# ****Alignment****
# sequence: gb|CP000139.1| Bacteroides vulgatus ATCC 8482, complete genome
# length: 5163189
# e value: 541.375
# CAC-GTTGAGACAGCGTCCA
# ||| ||||||||||||||||
# CACGGTTGAGACAGCGTCCA
# 1
# 19
# ****Alignment****
# sequence: gb|CP000139.1| Bacteroides vulgatus ATCC 8482, complete genome
# length: 5163189
# e value: 541.375
# CAC-GTTGAGACAGCGTCCA
# ||| ||||||||||||||||
# CACGGTTGAGACAGCGTCCA
# 1
# 19
# ****Alignment****
# sequence: ref|XM_001486474.1| Meyerozyma guilliermondii ATCC 6260 hypothetical protein (PGUG_02195) partial mRNA
# length: 1950
# e value: 541.375
# CGTTGAGACAGCGTCCAAA
# ||||||||||| |||||||
# CGTTGAGACAGGGTCCAAA
# 0
# 18
# ****Alignment****
# sequence: emb|AJ720391.1| Gallus gallus mRNA for hypothetical protein, clone 16m1
# length: 1655
# e value: 541.375
# TTGAGACAGCGTCCAA
# ||||||||||||||||
# TTGAGACAGCGTCCAA
# 0
# 16
# ****Alignment****
# sequence: emb|AJ720273.1| Gallus gallus mRNA for hypothetical protein, clone 13o18
# length: 1458
# e value: 541.375
# TTGAGACAGCGTCCAA
# ||||||||||||||||
# TTGAGACAGCGTCCAA
# 0
# 16
# ****Alignment****
# sequence: emb|AJ494848.1| Oikopleura dioica H3.1 gene, H4.1 gene, H1.1 gene, and H2A.1 gene
# length: 5705
# e value: 541.375
# TGAGACAGCGTCCAAA
# ||||||||||||||||
# TGAGACAGCGTCCAAA
# 0
# 16
# ****Alignment****
# sequence: emb|CT010451.9| Mouse DNA sequence from clone RP23-103I7 on chromosome 9, complete sequence
# length: 214871
# e value: 541.375
# TTGAGACAGCGTCCAA
# ||||||||||||||||
# TTGAGACAGCGTCCAA
# 0
# 16
# ****Alignment****
# sequence: gb|AC134849.5| Mus musculus BAC clone RP24-207G4 from 9, complete sequence
# length: 151630
# e value: 541.375
# TTGAGACAGCGTCCAA
# ||||||||||||||||
# TTGAGACAGCGTCCAA
# 0
# 16
# ****Alignment****
# sequence: emb|X68428.1| P.niger gene for 23S rRNA
# length: 2900
# e value: 541.375
# GTTGAGACAGCGTCCAAAT
# |||||||||||||||| ||
# GTTGAGACAGCGTCCAGAT
# 0
# 18

# %%
E_VALUE_THRESH = 1e-20 

for record in NCBIXML.parse(open("results.xml")): 
    if record.alignments: 
        print("\n") 
        print("query: %s" % record.query[:100]) 
        for align in record.alignments: 
            for hsp in align.hsps: 
                if hsp.expect < E_VALUE_THRESH: 
                    print("match: %s " % align.title[:100])

# %%
# %%time

E_VALUE_THRESH = 0.04

cross_dict = {}
for target in targets_left:
    list_of_cross_species = []
    
    result_handle = NCBIWWW.qblast("blastn", "nt", target)
    
    with open("targe_blast.xml", "w") as out_handle:
        out_handle.write(result_handle.read())
    result_handle.close()
    
    result_handle = open("targe_blast.xml")
    
    blast_record = NCBIXML.read(result_handle)
    for alignment in blast_record.alignments:
        for hsp in alignment.hsps:
            if hsp.expect < E_VALUE_THRESH:
                list_of_cross_species = list_of_cross_species.add(alignment.title) #.split('|')[4]
    cross_dict[target] = list_of_cross_species
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <timed exec> in <module>()
#
# /opt/miniconda3/envs/genomics/lib/python3.5/site-packages/Bio/Blast/NCBIWWW.py in qblast(program, database, sequence, url_base, auto_format, composition_based_statistics, db_genetic_code, endpoints, entrez_query, expect, filter, gapcosts, genetic_code, hitlist_size, i_thresh, layout, lcase_mask, matrix_name, nucl_penalty, nucl_reward, other_advanced, perc_ident, phi_pattern, query_file, query_believe_defline, query_from, query_to, searchsp_eff, service, threshold, ungapped_alignment, word_size, short_query, alignments, alignment_view, descriptions, entrez_links_new_window, expect_low, expect_high, format_entrez_query, format_object, format_type, ncbi_gi, results_file, show_overview, megablast, template_type, template_length)
#     211         wait = qblast._previous + delay - current
#     212         if wait > 0:
# --> 213             time.sleep(wait)
#     214             qblast._previous = current + wait
#     215         else:
#
# KeyboardInterrupt:

# %% [markdown]
# Candidates whose PAM-proximal
# 12 bp sequence appeared in the HOMG collection were subsequently excluded. An algorithm of CRISPR Design tool
# (ref 20 and http://crispr.mit.edu/about) was used to score the
# off-target effect for the remaining target candidates. The
# candidates were then ranked with an index scored from 100%
# to 0% (Supplemental Figure S4), and the ones with a score
# lower than 45% were further removed.

# %%
blast_record

# %%
blast_record = NCBIXML.read(open('blast_result.xml','r'))
for alignment in blast_record.alignments:
    print(alignment)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-112-a991ab9715ac> in <module>()
# ----> 1 blast_record = NCBIXML.read(open('blast_result.xml','r'))
#       2 for alignment in blast_record.alignments:
#       3     print(alignment)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'blast_result.xml'

# %% [markdown]
# # Gene mapping

# %%
from Bio.SeqUtils.Mapper import MapPosition

def use_genbank(self):
    return str(self.to_genbank())
MapPosition.__str__ = use_genbank
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-57-2edd9b407358> in <module>()
# ----> 1 from Bio.SeqUtils.Mapper import MapPosition
#       2
#       3 def use_genbank(self):
#       4     return str(self.to_genbank())
#       5 MapPosition.__str__ = use_genbank
#
# ImportError: No module named 'Bio.SeqUtils.Mapper'
